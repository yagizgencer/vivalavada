# %% [markdown]
# ## *Project milestone 3*

# %%
import pandas as pd
import numpy as np
from helpers import *
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator
from geopy.geocoders import Nominatim
import folium
from folium.plugins import HeatMap
from IPython.display import display
from geopy.distance import geodesic
import math
from statsmodels.stats import diagnostic
from scipy import stats
import statsmodels.api as sm
import statsmodels.formula.api as smf
import holoviews as hv
from holoviews import opts, dim
from bokeh.sampledata.les_mis import data
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## *Quick summary of project milestone 2*
# In project milestone 2, we performed an extensive data preprocessing. Specifically, we were given data from the websites: RateBeer and BeerAdvocate. Since we wanted to combine these two datasets and then perform further analysis, we needed a way to merge them into a single datasets by taking care of many intersection and consistency issues, such as the same users appearing in both websites or the same beer being assigned to different beer styles. We cleaned the data, put it in a format that is more suitable for our analysis and filtered it based on the set of locations and year range to be considered. Lastly, we performed some exploratory data analysis to get a better understanding of the data.
#
# The resulting datasets were saved in the "FilteredData" folder. In this milestone, we load these datasets and perform further analysis on beer preferences and their evolution with respect to time and location.

# %%
beers = pd.read_csv("dataset/FilteredData/beers.csv")
breweries = pd.read_csv("dataset/FilteredData/breweries.csv")
ratings = pd.read_csv("dataset/FilteredData/ratings.csv", dtype = {'user_id': str})
users = pd.read_csv("dataset/FilteredData/users.csv", dtype = {'user_id': str})

# %% [markdown]
# ## *Extracting the beer preferences at each location for each year*

# %% [markdown]
# We define the beer preference similarity between locations based on two different criteria:
#
# Their preferred beer styles or preferred locations of breweries. For example, if we examine a pair of locations and the ratings coming from these locations indicate that they both prefer "Imperial Stout" as the beer style or they both prefer beers from "Belgium" as the brewery location, then we say that these locations are similar in terms of their beer preference.
#
# For each criterion (beer style or brewery location), we define the "preference" again based on two different criteria: quantitative or qualitative (popularity-wise or rating-wise). As the names indicate, for each location the popularity-based approach captures the beer style or brewery location that got the highest number of ratings, whereas the rating-based approach captures the beer style or brewery location that got the highest average rating.
#
# Note that for the popularity-based approach, we require a style or brewery location to be at least as popular (in terms of its percentage in total number of ratings) as its total global popularity. For the rating-based approach, we apply a threshold (10 for styles and 20 for brewery locations) for the number of ratings that a style or brewery location should have in order to be considered.
#
# The functions "location_style_stats()" and "location_brewery_country_stats()" used to extract the beer preferences can be found in the helpers.py file.

# %% [markdown]
# ### *Popularity-based beer style preferences*

# %%
all_years_list = sorted(ratings['year'].unique())
style_popularities_by_year = pd.DataFrame()
for year in all_years_list:
    location_style = location_style_stats(ratings.copy(), users.copy(), year, loc_style_threshold = 10, rating_flag = False)
    location_style_groupedby_loc = location_style.groupby('location')
    idx_most_popular = location_style_groupedby_loc['popularity_percentage'].idxmax()
    most_popular_styles_by_location = location_style.loc[idx_most_popular]
    most_popular_styles_by_location = most_popular_styles_by_location[['location', 'style']]
    most_popular_styles_by_location.set_index('location', inplace = True)
    most_popular_styles_by_location = most_popular_styles_by_location.rename(columns = {'style': str(year)})
    style_popularities_by_year = pd.concat([style_popularities_by_year, most_popular_styles_by_location], axis = 1)

style_popularities_by_year
# Out:
#                                               2006                  2007  \
# location
# Australia                               Pale Lager            Pale Lager
# Belgium                         Belgian Strong Ale    Belgian Strong Ale
# Brazil                                  Pale Lager            Pale Lager
# Canada                                  Pale Lager            Pale Lager
# Croatia                                 Pale Lager            Pale Lager
# ...                                            ...                   ...
# United States, Virginia       India Pale Ale (IPA)  India Pale Ale (IPA)
# United States, Washington     India Pale Ale (IPA)  India Pale Ale (IPA)
# United States, West Virginia  India Pale Ale (IPA)            Pale Lager
# United States, Wisconsin      India Pale Ale (IPA)  India Pale Ale (IPA)
# United States, Wyoming        India Pale Ale (IPA)  India Pale Ale (IPA)
#
#                                               2008                  2009  \
# location
# Australia                               Pale Lager            Pale Lager
# Belgium                         Belgian Strong Ale    Belgian Strong Ale
# Brazil                                  Pale Lager            Pale Lager
# Canada                                  Pale Lager            Pale Lager
# Croatia                                 Pale Lager            Pale Lager
# ...                                            ...                   ...
# United States, Virginia       India Pale Ale (IPA)  India Pale Ale (IPA)
# United States, Washington     India Pale Ale (IPA)  India Pale Ale (IPA)
# United States, West Virginia  India Pale Ale (IPA)  India Pale Ale (IPA)
# United States, Wisconsin      India Pale Ale (IPA)  India Pale Ale (IPA)
# United States, Wyoming                  Pale Lager            Pale Lager
#
#                                               2010                  2011  \
# location
# Australia                               Pale Lager            Pale Lager
# Belgium                         Belgian Strong Ale    Belgian Strong Ale
# Brazil                                  Pale Lager            Pale Lager
# Canada                                  Pale Lager            Pale Lager
# Croatia                                   Pilsener            Pale Lager
# ...                                            ...                   ...
# United States, Virginia       India Pale Ale (IPA)  India Pale Ale (IPA)
# United States, Washington     India Pale Ale (IPA)  India Pale Ale (IPA)
# United States, West Virginia  India Pale Ale (IPA)  India Pale Ale (IPA)
# United States, Wisconsin      India Pale Ale (IPA)  India Pale Ale (IPA)
# United States, Wyoming                  Pale Lager          Imperial IPA
#
#                                               2012                  2013  \
# location
# Australia                               Pale Lager  India Pale Ale (IPA)
# Belgium                         Belgian Strong Ale    Belgian Strong Ale
# Brazil                                  Pale Lager            Pale Lager
# Canada                        India Pale Ale (IPA)            Pale Lager
# Croatia                                 Pale Lager            Pale Lager
# ...                                            ...                   ...
# United States, Virginia       India Pale Ale (IPA)  India Pale Ale (IPA)
# United States, Washington     India Pale Ale (IPA)  India Pale Ale (IPA)
# United States, West Virginia  India Pale Ale (IPA)  India Pale Ale (IPA)
# United States, Wisconsin      India Pale Ale (IPA)        Imperial Stout
# United States, Wyoming              Imperial Stout        Imperial Stout
#
#                                               2014                  2015  \
# location
# Australia                     India Pale Ale (IPA)     American Pale Ale
# Belgium                                Belgian Ale           Belgian Ale
# Brazil                                  Pale Lager            Pale Lager
# Canada                           American Pale Ale                Saison
# Croatia                                 Pale Lager            Pale Lager
# ...                                            ...                   ...
# United States, Virginia       India Pale Ale (IPA)  India Pale Ale (IPA)
# United States, Washington     India Pale Ale (IPA)  India Pale Ale (IPA)
# United States, West Virginia  India Pale Ale (IPA)  India Pale Ale (IPA)
# United States, Wisconsin            Imperial Stout        Imperial Stout
# United States, Wyoming           American Pale Ale  India Pale Ale (IPA)
#
#                                               2016                  2017
# location
# Australia                        American Pale Ale  India Pale Ale (IPA)
# Belgium                                Belgian Ale        Imperial Stout
# Brazil                                  Pale Lager            Pale Lager
# Canada                                      Saison         Sour/Wild Ale
# Croatia                                 Pale Lager            Pale Lager
# ...                                            ...                   ...
# United States, Virginia       India Pale Ale (IPA)  India Pale Ale (IPA)
# United States, Washington     India Pale Ale (IPA)  India Pale Ale (IPA)
# United States, West Virginia            Pale Lager                Saison
# United States, Wisconsin            Imperial Stout        Imperial Stout
# United States, Wyoming        India Pale Ale (IPA)  India Pale Ale (IPA)
#
# [71 rows x 12 columns]

# %% [markdown]
# ### *Popularity-based beer style preferences - Top 3*

# %% [markdown]
# For beer style preferences, we also provide the dataframes containing the top 3 beer styles (instead of only the top one) for each location. These dataframes will be used for Jaccard beer style preference similary calculations between different locations in later parts of the notebook.

# %%
all_years_list = sorted(ratings['year'].unique())
style_popularities_by_year_top3 = pd.DataFrame()
for year in all_years_list:
    location_style = location_style_stats(ratings.copy(), users.copy(), year, loc_style_threshold = 10, rating_flag = False)
    location_style_groupedby_loc = location_style.groupby('location')
    idx_most_popular = location_style_groupedby_loc.apply(lambda x: x.nlargest(3, 'popularity_percentage')).index.values
    idx_most_popular = [x[1] for x in idx_most_popular]
    most_popular_styles_by_location = location_style.loc[idx_most_popular]
    three_most_popular_styles_by_location = most_popular_styles_by_location.groupby('location')['style'].agg(list).to_frame()
    three_most_popular_styles_by_location = three_most_popular_styles_by_location.rename(columns = {'style': str(year)})
    style_popularities_by_year_top3 = pd.concat([style_popularities_by_year_top3, three_most_popular_styles_by_location], axis = 1)
    
style_popularities_by_year_top3
# Out:
#                                                                            2006  \
# location
# Australia                          [Pale Lager, Pilsener, Golden Ale/Blond Ale]
# Belgium                         [Belgian Strong Ale, Belgian Ale, Abbey Tripel]
# Brazil                                [Pale Lager, Pilsener, German Hefeweizen]
# Canada                           [Pale Lager, Golden Ale/Blond Ale, Fruit Beer]
# Croatia                                      [Pale Lager, Pilsener, Fruit Beer]
# ...                                                                         ...
# United States, Virginia       [India Pale Ale (IPA), Imperial Stout, Imperia...
# United States, Washington     [India Pale Ale (IPA), Imperial Stout, America...
# United States, West Virginia  [India Pale Ale (IPA), Imperial IPA, Imperial ...
# United States, Wisconsin         [India Pale Ale (IPA), Imperial Stout, Porter]
# United States, Wyoming           [India Pale Ale (IPA), Porter, Imperial Stout]
#
#                                                                            2007  \
# location
# Australia                          [Pale Lager, Pilsener, Golden Ale/Blond Ale]
# Belgium                         [Belgian Strong Ale, Belgian Ale, Abbey Tripel]
# Brazil                            [Pale Lager, Belgian Strong Ale, Belgian Ale]
# Canada                             [Pale Lager, Golden Ale/Blond Ale, Pilsener]
# Croatia                                      [Pale Lager, Pilsener, Fruit Beer]
# ...                                                                         ...
# United States, Virginia       [India Pale Ale (IPA), Porter, American Pale Ale]
# United States, Washington          [India Pale Ale (IPA), Porter, Imperial IPA]
# United States, West Virginia  [Pale Lager, India Pale Ale (IPA), American Pa...
# United States, Wisconsin         [India Pale Ale (IPA), Imperial Stout, Porter]
# United States, Wyoming        [India Pale Ale (IPA), American Pale Ale, Gold...
#
#                                                                            2008  \
# location
# Australia                          [Pale Lager, Pilsener, Golden Ale/Blond Ale]
# Belgium                         [Belgian Strong Ale, Belgian Ale, Abbey Tripel]
# Brazil                               [Pale Lager, Pilsener, Belgian Strong Ale]
# Canada                        [Pale Lager, India Pale Ale (IPA), Belgian Str...
# Croatia                                      [Pale Lager, Pilsener, Fruit Beer]
# ...                                                                         ...
# United States, Virginia       [India Pale Ale (IPA), Imperial Stout, Imperia...
# United States, Washington     [India Pale Ale (IPA), Imperial Stout, Belgian...
# United States, West Virginia      [India Pale Ale (IPA), Pale Lager, Amber Ale]
# United States, Wisconsin         [India Pale Ale (IPA), Imperial Stout, Porter]
# United States, Wyoming                  [Pale Lager, Imperial Stout, Amber Ale]
#
#                                                                            2009  \
# location
# Australia                          [Pale Lager, Golden Ale/Blond Ale, Pilsener]
# Belgium                           [Belgian Strong Ale, Belgian Ale, Pale Lager]
# Brazil                                [Pale Lager, Pilsener, German Hefeweizen]
# Canada                        [Pale Lager, Belgian Strong Ale, Golden Ale/Bl...
# Croatia                                    [Pale Lager, Pilsener, Dunkel/Tmavý]
# ...                                                                         ...
# United States, Virginia       [India Pale Ale (IPA), Imperial Stout, Imperia...
# United States, Washington     [India Pale Ale (IPA), Imperial IPA, Imperial ...
# United States, West Virginia            [India Pale Ale (IPA), Porter, Witbier]
# United States, Wisconsin      [India Pale Ale (IPA), Imperial Stout, Imperia...
# United States, Wyoming        [Pale Lager, Imperial Stout, American Strong A...
#
#                                                                            2010  \
# location
# Australia                     [Pale Lager, Golden Ale/Blond Ale, American Pa...
# Belgium                         [Belgian Strong Ale, Belgian Ale, Abbey Tripel]
# Brazil                               [Pale Lager, Belgian Strong Ale, Pilsener]
# Canada                        [Pale Lager, Belgian Strong Ale, Golden Ale/Bl...
# Croatia                                    [Pilsener, Pale Lager, Dunkel/Tmavý]
# ...                                                                         ...
# United States, Virginia       [India Pale Ale (IPA), Imperial Stout, Imperia...
# United States, Washington     [India Pale Ale (IPA), Imperial IPA, American ...
# United States, West Virginia   [India Pale Ale (IPA), Imperial IPA, Pale Lager]
# United States, Wisconsin      [India Pale Ale (IPA), Imperial Stout, Imperia...
# United States, Wyoming        [Pale Lager, India Pale Ale (IPA), American St...
#
#                                                                            2011  \
# location
# Australia                     [Pale Lager, American Pale Ale, Golden Ale/Blo...
# Belgium                         [Belgian Strong Ale, Belgian Ale, Abbey Tripel]
# Brazil                               [Pale Lager, Belgian Strong Ale, Pilsener]
# Canada                        [Pale Lager, Golden Ale/Blond Ale, Spice/Herb/...
# Croatia                                      [Pale Lager, Pilsener, Fruit Beer]
# ...                                                                         ...
# United States, Virginia       [India Pale Ale (IPA), Imperial Stout, Imperia...
# United States, Washington     [India Pale Ale (IPA), Imperial Stout, Imperia...
# United States, West Virginia  [India Pale Ale (IPA), Pale Lager, Spice/Herb/...
# United States, Wisconsin      [India Pale Ale (IPA), Imperial Stout, Imperia...
# United States, Wyoming           [Imperial IPA, American Pale Ale, Barley Wine]
#
#                                                                            2012  \
# location
# Australia                     [Pale Lager, American Pale Ale, Golden Ale/Blo...
# Belgium                         [Belgian Strong Ale, Belgian Ale, Abbey Tripel]
# Brazil                               [Pale Lager, Belgian Strong Ale, Pilsener]
# Canada                        [India Pale Ale (IPA), Pale Lager, Belgian Str...
# Croatia                                      [Pale Lager, Fruit Beer, Pilsener]
# ...                                                                         ...
# United States, Virginia       [India Pale Ale (IPA), Imperial IPA, Imperial ...
# United States, Washington     [India Pale Ale (IPA), Imperial Stout, Imperia...
# United States, West Virginia  [India Pale Ale (IPA), Pale Lager, Belgian Str...
# United States, Wisconsin      [India Pale Ale (IPA), Imperial Stout, Imperia...
# United States, Wyoming                     [Imperial Stout, Pale Lager, Porter]
#
#                                                                            2013  \
# location
# Australia                     [India Pale Ale (IPA), American Pale Ale, Pale...
# Belgium                         [Belgian Strong Ale, Belgian Ale, Abbey Tripel]
# Brazil                        [Pale Lager, Belgian Strong Ale, German Hefewe...
# Canada                                  [Pale Lager, American Pale Ale, Saison]
# Croatia                                      [Pale Lager, Pilsener, Fruit Beer]
# ...                                                                         ...
# United States, Virginia       [India Pale Ale (IPA), Imperial IPA, Imperial ...
# United States, Washington     [India Pale Ale (IPA), Imperial Stout, Imperia...
# United States, West Virginia  [India Pale Ale (IPA), Imperial IPA, Spice/Her...
# United States, Wisconsin                 [Imperial Stout, Imperial IPA, Porter]
# United States, Wyoming                     [Imperial Stout, Pale Lager, Porter]
#
#                                                                            2014  \
# location
# Australia                     [India Pale Ale (IPA), American Pale Ale, Pale...
# Belgium                         [Belgian Ale, Belgian Strong Ale, Abbey Tripel]
# Brazil                        [Pale Lager, Belgian Strong Ale, German Hefewe...
# Canada                                  [American Pale Ale, Saison, Pale Lager]
# Croatia                               [Pale Lager, Pilsener, German Hefeweizen]
# ...                                                                         ...
# United States, Virginia       [India Pale Ale (IPA), Imperial IPA, Imperial ...
# United States, Washington     [India Pale Ale (IPA), Imperial IPA, Imperial ...
# United States, West Virginia  [India Pale Ale (IPA), Imperial IPA, Imperial ...
# United States, Wisconsin      [Imperial Stout, Imperial IPA, American Pale Ale]
# United States, Wyoming                  [American Pale Ale, Pale Lager, Porter]
#
#                                                                            2015  \
# location
# Australia                     [American Pale Ale, Pale Lager, Golden Ale/Blo...
# Belgium                               [Belgian Ale, Belgian Strong Ale, Saison]
# Brazil                        [Pale Lager, Belgian Strong Ale, German Hefewe...
# Canada                               [Saison, American Pale Ale, Sour/Wild Ale]
# Croatia                               [Pale Lager, Pilsener, American Pale Ale]
# ...                                                                         ...
# United States, Virginia       [India Pale Ale (IPA), Imperial Stout, Imperia...
# United States, Washington     [India Pale Ale (IPA), Imperial IPA, Imperial ...
# United States, West Virginia         [India Pale Ale (IPA), Pale Lager, Porter]
# United States, Wisconsin      [Imperial Stout, Imperial IPA, American Pale Ale]
# United States, Wyoming               [India Pale Ale (IPA), Pale Lager, Porter]
#
#                                                                            2016  \
# location
# Australia                     [American Pale Ale, Pale Lager, Golden Ale/Blo...
# Belgium                         [Belgian Ale, Belgian Strong Ale, Abbey Tripel]
# Brazil                        [Pale Lager, Belgian Strong Ale, German Hefewe...
# Canada                               [Saison, Sour/Wild Ale, American Pale Ale]
# Croatia                               [Pale Lager, American Pale Ale, Pilsener]
# ...                                                                         ...
# United States, Virginia       [India Pale Ale (IPA), Imperial IPA, Imperial ...
# United States, Washington     [India Pale Ale (IPA), Imperial IPA, American ...
# United States, West Virginia                     [Pale Lager, Porter, Pilsener]
# United States, Wisconsin      [Imperial Stout, Imperial IPA, American Pale Ale]
# United States, Wyoming               [India Pale Ale (IPA), Pale Lager, Porter]
#
#                                                                            2017
# location
# Australia                     [India Pale Ale (IPA), American Pale Ale, Pale...
# Belgium                       [Imperial Stout, Belgian Ale, Belgian Strong Ale]
# Brazil                        [Pale Lager, Belgian Strong Ale, Golden Ale/Bl...
# Canada                                           [Sour/Wild Ale, Saison, Stout]
# Croatia                               [Pale Lager, American Pale Ale, Pilsener]
# ...                                                                         ...
# United States, Virginia       [India Pale Ale (IPA), Imperial IPA, Imperial ...
# United States, Washington     [India Pale Ale (IPA), Imperial IPA, Imperial ...
# United States, West Virginia                       [Saison, Pale Lager, Porter]
# United States, Wisconsin      [Imperial Stout, Imperial IPA, American Pale Ale]
# United States, Wyoming        [India Pale Ale (IPA), American Pale Ale, Sour...
#
# [71 rows x 12 columns]

# %% [markdown]
# ### *Rating-based style preferences*

# %%
all_years_list = sorted(ratings['year'].unique())
style_ratings_by_year = pd.DataFrame()
for year in all_years_list:
    location_style = location_style_stats(ratings.copy(), users.copy(), year, loc_style_threshold = 10, rating_flag = True)
    location_style_groupedby_loc = location_style.groupby('location')
    idx_highest_rated = location_style_groupedby_loc['z_score'].idxmax()
    highest_rated_styles_by_location = location_style.loc[idx_highest_rated]
    highest_rated_styles_by_location = highest_rated_styles_by_location[['location', 'style']]
    highest_rated_styles_by_location.set_index('location', inplace = True)
    highest_rated_styles_by_location = highest_rated_styles_by_location.rename(columns = {'style': str(year)})
    style_ratings_by_year = pd.concat([style_ratings_by_year, highest_rated_styles_by_location], axis = 1)

style_ratings_by_year
# Out:
#                                             2006                   2007  \
# location
# Australia                          Abt/Quadrupel          Abt/Quadrupel
# Belgium                            Abt/Quadrupel          Abt/Quadrupel
# Brazil                         German Hefeweizen          Abt/Quadrupel
# Canada                             Abt/Quadrupel          Abt/Quadrupel
# Croatia                       Belgian Strong Ale                 Porter
# ...                                          ...                    ...
# United States, Virginia            Abt/Quadrupel          Abt/Quadrupel
# United States, Washington          Abt/Quadrupel          Abt/Quadrupel
# United States, West Virginia          Doppelbock         Imperial Stout
# United States, Wisconsin           Sour/Wild Ale  Lambic Style - Gueuze
# United States, Wyoming              Imperial IPA         Imperial Stout
#
#                                                2008                   2009  \
# location
# Australia                             Abt/Quadrupel          Abt/Quadrupel
# Belgium                               Abt/Quadrupel          Abt/Quadrupel
# Brazil                                Abt/Quadrupel     Belgian Strong Ale
# Canada                                Abt/Quadrupel          Abt/Quadrupel
# Croatia                               Abt/Quadrupel         Imperial Stout
# ...                                             ...                    ...
# United States, Virginia              Sour Red/Brown  Lambic Style - Gueuze
# United States, Washington     Lambic Style - Gueuze         Sour Red/Brown
# United States, West Virginia          Abt/Quadrupel          Abt/Quadrupel
# United States, Wisconsin      Lambic Style - Gueuze         Imperial Stout
# United States, Wyoming                        Stout          Sour/Wild Ale
#
#                                                   2010                   2011  \
# location
# Australia                                Abt/Quadrupel          Abt/Quadrupel
# Belgium                                  Abt/Quadrupel  Lambic Style - Gueuze
# Brazil                                  Imperial Stout   Lambic Style - Fruit
# Canada                                   Abt/Quadrupel          Abt/Quadrupel
# Croatia                                 Imperial Stout         Imperial Stout
# ...                                                ...                    ...
# United States, Virginia                  Sour/Wild Ale  Lambic Style - Gueuze
# United States, Washington     Lambic Style - Unblended  Lambic Style - Gueuze
# United States, West Virginia             Abt/Quadrupel          Abt/Quadrupel
# United States, Wisconsin         Lambic Style - Gueuze  Lambic Style - Gueuze
# United States, Wyoming                  Imperial Stout           Imperial IPA
#
#                                                   2012                   2013  \
# location
# Australia                                Abt/Quadrupel                Eisbock
# Belgium                                  Abt/Quadrupel         Imperial Stout
# Brazil                                   Abt/Quadrupel          Abt/Quadrupel
# Canada                           Lambic Style - Gueuze          Abt/Quadrupel
# Croatia                                 Imperial Stout         Imperial Stout
# ...                                                ...                    ...
# United States, Virginia       Lambic Style - Unblended  Lambic Style - Gueuze
# United States, Washington        Lambic Style - Gueuze  Lambic Style - Gueuze
# United States, West Virginia             Abt/Quadrupel          Abt/Quadrupel
# United States, Wisconsin         Lambic Style - Gueuze  Lambic Style - Gueuze
# United States, Wyoming                  Imperial Stout         Imperial Stout
#
#                                                2014                   2015  \
# location
# Australia                             Abt/Quadrupel  Lambic Style - Gueuze
# Belgium                        American Strong Ale          Imperial Stout
# Brazil                                Abt/Quadrupel          Abt/Quadrupel
# Canada                                Abt/Quadrupel  Lambic Style - Gueuze
# Croatia                              Imperial Stout         Imperial Stout
# ...                                             ...                    ...
# United States, Virginia       Lambic Style - Gueuze  Lambic Style - Gueuze
# United States, Washington     Lambic Style - Gueuze  Lambic Style - Gueuze
# United States, West Virginia         Imperial Stout   Lambic Style - Fruit
# United States, Wisconsin             Imperial Stout  Lambic Style - Gueuze
# United States, Wyoming               Sour Red/Brown         Imperial Stout
#
#                                                   2016                   2017
# location
# Australia                               Imperial Stout          Abt/Quadrupel
# Belgium                                 Imperial Stout         Imperial Stout
# Brazil                                   Abt/Quadrupel           Abbey Tripel
# Canada                           Lambic Style - Gueuze  Lambic Style - Gueuze
# Croatia                                  Abt/Quadrupel   Lambic Style - Fruit
# ...                                                ...                    ...
# United States, Virginia          Lambic Style - Gueuze  Lambic Style - Gueuze
# United States, Washington        Lambic Style - Gueuze  Lambic Style - Gueuze
# United States, West Virginia            Imperial Stout          Abt/Quadrupel
# United States, Wisconsin      Lambic Style - Unblended  Lambic Style - Gueuze
# United States, Wyoming                  Imperial Stout         Imperial Stout
#
# [71 rows x 12 columns]

# %% [markdown]
# ### *Rating-based beer style preferences - Top 3*

# %%
all_years_list = sorted(ratings['year'].unique())
style_ratings_by_year_top3 = pd.DataFrame()
for year in all_years_list:
    location_style = location_style_stats(ratings.copy(), users.copy(), year, loc_style_threshold = 10, rating_flag = True)
    location_style_groupedby_loc = location_style.groupby('location')
    idx_highest_rated = location_style_groupedby_loc.apply(lambda x: x.nlargest(3, 'z_score')).index.values
    idx_highest_rated = [x[1] for x in idx_highest_rated]
    highest_rated_styles_by_location = location_style.loc[idx_highest_rated]
    three_highest_rated_styles_by_location = highest_rated_styles_by_location.groupby('location')['style'].agg(list).to_frame()
    three_highest_rated_styles_by_location = three_highest_rated_styles_by_location.rename(columns = {'style': str(year)})
    style_ratings_by_year_top3 = pd.concat([style_ratings_by_year_top3, three_highest_rated_styles_by_location], axis = 1)
    
style_ratings_by_year_top3
# Out:
#                                                                            2006  \
# location
# Australia                     [Abt/Quadrupel, Imperial IPA, Lambic Style - G...
# Belgium                       [Abt/Quadrupel, Lambic Style - Gueuze, Sour/Wi...
# Brazil                                [German Hefeweizen, Pilsener, Pale Lager]
# Canada                        [Abt/Quadrupel, Lambic Style - Unblended, Impe...
# Croatia                        [Belgian Strong Ale, Abbey Tripel, Abbey Dubbel]
# ...                                                                         ...
# United States, Virginia                 [Abt/Quadrupel, Sour/Wild Ale, Eisbock]
# United States, Washington              [Abt/Quadrupel, Imperial Stout, Eisbock]
# United States, West Virginia         [Doppelbock, Imperial Stout, Imperial IPA]
# United States, Wisconsin                [Sour/Wild Ale, Eisbock, Abt/Quadrupel]
# United States, Wyoming        [Imperial IPA, Imperial Stout, Belgian Strong ...
#
#                                                                            2007  \
# location
# Australia                         [Abt/Quadrupel, Imperial Stout, Imperial IPA]
# Belgium                           [Abt/Quadrupel, Imperial Stout, Imperial IPA]
# Brazil                         [Abt/Quadrupel, Barley Wine, Belgian Strong Ale]
# Canada                        [Abt/Quadrupel, Lambic Style - Unblended, Impe...
# Croatia                              [Porter, Belgian Strong Ale, Abbey Dubbel]
# ...                                                                         ...
# United States, Virginia          [Abt/Quadrupel, Sour/Wild Ale, Imperial Stout]
# United States, Washington              [Abt/Quadrupel, Imperial Stout, Eisbock]
# United States, West Virginia        [Imperial Stout, Sweet Stout, Imperial IPA]
# United States, Wisconsin      [Lambic Style - Gueuze, Abt/Quadrupel, Sour/Wi...
# United States, Wyoming                   [Imperial Stout, Imperial IPA, Porter]
#
#                                                                            2008  \
# location
# Australia                         [Abt/Quadrupel, Imperial IPA, Imperial Stout]
# Belgium                            [Abt/Quadrupel, Imperial Stout, Barley Wine]
# Brazil                        [Abt/Quadrupel, Imperial Stout, Belgian Strong...
# Canada                           [Abt/Quadrupel, Imperial Stout, Sour/Wild Ale]
# Croatia                          [Abt/Quadrupel, Imperial Stout, Baltic Porter]
# ...                                                                         ...
# United States, Virginia       [Sour Red/Brown, Abt/Quadrupel, Lambic Style -...
# United States, Washington     [Lambic Style - Gueuze, Sour Red/Brown, Sour/W...
# United States, West Virginia      [Abt/Quadrupel, Imperial IPA, Imperial Stout]
# United States, Wisconsin      [Lambic Style - Gueuze, Sour/Wild Ale, Abt/Qua...
# United States, Wyoming            [Stout, Imperial Stout, India Pale Ale (IPA)]
#
#                                                                            2009  \
# location
# Australia                              [Abt/Quadrupel, Eisbock, Imperial Stout]
# Belgium                            [Abt/Quadrupel, Imperial Stout, Barley Wine]
# Brazil                        [Belgian Strong Ale, Abbey Tripel, India Pale ...
# Canada                        [Abt/Quadrupel, Lambic Style - Gueuze, Imperia...
# Croatia                       [Imperial Stout, India Pale Ale (IPA), Belgian...
# ...                                                                         ...
# United States, Virginia       [Lambic Style - Gueuze, Sour Red/Brown, Imperi...
# United States, Washington     [Sour Red/Brown, Lambic Style - Unblended, Lam...
# United States, West Virginia      [Abt/Quadrupel, Imperial Stout, Abbey Tripel]
# United States, Wisconsin         [Imperial Stout, Abt/Quadrupel, Sour/Wild Ale]
# United States, Wyoming          [Sour/Wild Ale, Imperial Stout, Sour Red/Brown]
#
#                                                                            2010  \
# location
# Australia                              [Abt/Quadrupel, Imperial Stout, Eisbock]
# Belgium                       [Abt/Quadrupel, Imperial Stout, Lambic Style -...
# Brazil                        [Imperial Stout, Belgian Strong Ale, Lambic St...
# Canada                        [Abt/Quadrupel, Grodziskie/Gose/Lichtenhainer,...
# Croatia                       [Imperial Stout, India Pale Ale (IPA), Weizen ...
# ...                                                                         ...
# United States, Virginia       [Sour/Wild Ale, Weizen Bock, Lambic Style - Un...
# United States, Washington     [Lambic Style - Unblended, Lambic Style - Gueu...
# United States, West Virginia  [Abt/Quadrupel, Imperial Stout, Belgian Strong...
# United States, Wisconsin      [Lambic Style - Gueuze, Abt/Quadrupel, Sour/Wi...
# United States, Wyoming        [Imperial Stout, Imperial IPA, India Pale Ale ...
#
#                                                                            2011  \
# location
# Australia                     [Abt/Quadrupel, Imperial Stout, American Stron...
# Belgium                       [Lambic Style - Gueuze, Abt/Quadrupel, Imperia...
# Brazil                              [Lambic Style - Fruit, Porter, Barley Wine]
# Canada                        [Abt/Quadrupel, Lambic Style - Unblended, Lamb...
# Croatia                             [Imperial Stout, Imperial IPA, Barley Wine]
# ...                                                                         ...
# United States, Virginia         [Lambic Style - Gueuze, Eisbock, Abt/Quadrupel]
# United States, Washington     [Lambic Style - Gueuze, Lambic Style - Unblend...
# United States, West Virginia      [Abt/Quadrupel, Baltic Porter, Foreign Stout]
# United States, Wisconsin      [Lambic Style - Gueuze, Abt/Quadrupel, Imperia...
# United States, Wyoming        [Imperial IPA, Imperial Stout, India Pale Ale ...
#
#                                                                            2012  \
# location
# Australia                     [Abt/Quadrupel, American Strong Ale , Lambic S...
# Belgium                       [Abt/Quadrupel, Imperial Stout, American Stron...
# Brazil                                   [Abt/Quadrupel, Old Ale, Abbey Tripel]
# Canada                        [Lambic Style - Gueuze, Abt/Quadrupel, Lambic ...
# Croatia                             [Imperial Stout, Barley Wine, Imperial IPA]
# ...                                                                         ...
# United States, Virginia       [Lambic Style - Unblended, Lambic Style - Gueu...
# United States, Washington     [Lambic Style - Gueuze, Imperial Stout, Sour/W...
# United States, West Virginia        [Abt/Quadrupel, Imperial Stout, Doppelbock]
# United States, Wisconsin      [Lambic Style - Gueuze, Lambic Style - Unblend...
# United States, Wyoming            [Imperial Stout, Abt/Quadrupel, Imperial IPA]
#
#                                                                            2013  \
# location
# Australia                       [Eisbock, Abt/Quadrupel, Lambic Style - Gueuze]
# Belgium                       [Imperial Stout, Eisbock, Lambic Style - Unble...
# Brazil                        [Abt/Quadrupel, Sour/Wild Ale, Belgian Strong ...
# Canada                        [Abt/Quadrupel, Lambic Style - Gueuze, Imperia...
# Croatia                            [Imperial Stout, Abbey Dubbel, Abbey Tripel]
# ...                                                                         ...
# United States, Virginia        [Lambic Style - Gueuze, Imperial Stout, Eisbock]
# United States, Washington     [Lambic Style - Gueuze, Lambic Style - Unblend...
# United States, West Virginia  [Abt/Quadrupel, Imperial Stout, Lambic Style -...
# United States, Wisconsin       [Lambic Style - Gueuze, Imperial Stout, Eisbock]
# United States, Wyoming                   [Imperial Stout, Barley Wine, Old Ale]
#
#                                                                            2014  \
# location
# Australia                     [Abt/Quadrupel, Imperial Stout, Lambic Style -...
# Belgium                       [American Strong Ale , Imperial Stout, Imperia...
# Brazil                        [Abt/Quadrupel, Imperial Stout, Lambic Style -...
# Canada                        [Abt/Quadrupel, Imperial Stout, Lambic Style -...
# Croatia                            [Imperial Stout, Weizen Bock, Abt/Quadrupel]
# ...                                                                         ...
# United States, Virginia       [Lambic Style - Gueuze, Lambic Style - Fruit, ...
# United States, Washington     [Lambic Style - Gueuze, Imperial Stout, Lambic...
# United States, West Virginia  [Imperial Stout, Lambic Style - Gueuze, Abt/Qu...
# United States, Wisconsin      [Imperial Stout, Lambic Style - Gueuze, Lambic...
# United States, Wyoming            [Sour Red/Brown, Barley Wine, Imperial Stout]
#
#                                                                            2015  \
# location
# Australia                     [Lambic Style - Gueuze, Weizen Bock, Abt/Quadr...
# Belgium                       [Imperial Stout, Lambic Style - Gueuze, Americ...
# Brazil                        [Abt/Quadrupel, Imperial Stout, American Stron...
# Canada                        [Lambic Style - Gueuze, Imperial Stout, Abt/Qu...
# Croatia                              [Imperial Stout, Black IPA, Abt/Quadrupel]
# ...                                                                         ...
# United States, Virginia       [Lambic Style - Gueuze, Imperial Stout, Lambic...
# United States, Washington     [Lambic Style - Gueuze, Lambic Style - Fruit, ...
# United States, West Virginia  [Lambic Style - Fruit, Imperial Stout, Bière d...
# United States, Wisconsin      [Lambic Style - Gueuze, Imperial Stout, Lambic...
# United States, Wyoming        [Imperial Stout, Abt/Quadrupel, American Stron...
#
#                                                                            2016  \
# location
# Australia                     [Imperial Stout, Lambic Style - Gueuze, Abt/Qu...
# Belgium                                    [Imperial Stout, Mead, Imperial IPA]
# Brazil                          [Abt/Quadrupel, Imperial Stout, Sour Red/Brown]
# Canada                        [Lambic Style - Gueuze, Imperial Stout, Lambic...
# Croatia                       [Abt/Quadrupel, Imperial Stout, American Stron...
# ...                                                                         ...
# United States, Virginia       [Lambic Style - Gueuze, Lambic Style - Fruit, ...
# United States, Washington     [Lambic Style - Gueuze, Lambic Style - Fruit, ...
# United States, West Virginia    [Imperial Stout, Sour Red/Brown, Abt/Quadrupel]
# United States, Wisconsin      [Lambic Style - Unblended, Lambic Style - Frui...
# United States, Wyoming                  [Imperial Stout, Imperial IPA, Old Ale]
#
#                                                                            2017
# location
# Australia                       [Abt/Quadrupel, Lambic Style - Gueuze, Old Ale]
# Belgium                       [Imperial Stout, Baltic Porter, American Stron...
# Brazil                        [Abbey Tripel, Belgian Strong Ale, Abt/Quadrupel]
# Canada                        [Lambic Style - Gueuze, Lambic Style - Unblend...
# Croatia                       [Lambic Style - Fruit, Imperial Stout, Lambic ...
# ...                                                                         ...
# United States, Virginia       [Lambic Style - Gueuze, Lambic Style - Unblend...
# United States, Washington     [Lambic Style - Gueuze, Imperial Stout, Sour R...
# United States, West Virginia    [Abt/Quadrupel, Imperial Stout, Sour Red/Brown]
# United States, Wisconsin      [Lambic Style - Gueuze, Lambic Style - Fruit, ...
# United States, Wyoming             [Imperial Stout, Sour/Wild Ale, Barley Wine]
#
# [71 rows x 12 columns]

# %% [markdown]
# ### *Popularity-based brewery location preferences*

# %%
all_years_list = sorted(ratings['year'].unique())
bc_popularities_by_year = pd.DataFrame()
for year in all_years_list:
    location_bc = location_brewery_country_stats(ratings.copy(), users.copy(), breweries.copy(), year, loc_brewery_threshold = 20, rating_flag = False)
    location_bc_gb_loc = location_bc.groupby('location')
    idx_most_popular = location_bc_gb_loc['popularity_percentage'].idxmax()
    most_popular_bc_by_location = location_bc.loc[idx_most_popular]
    most_popular_bc_by_location = most_popular_bc_by_location[['location', 'brewery_location']]
    most_popular_bc_by_location.set_index('location', inplace = True)
    most_popular_bc_by_location = most_popular_bc_by_location.rename(columns = {'brewery_location': str(year)})
    bc_popularities_by_year = pd.concat([bc_popularities_by_year, most_popular_bc_by_location], axis = 1)
    
bc_popularities_by_year
# Out:
#                                                      2006  \
# location
# Australia                                       Australia
# Belgium                                           Belgium
# Brazil                                             Brazil
# Canada                                             Canada
# Croatia                                           Belgium
# ...                                                   ...
# United States, Virginia         United States, California
# United States, Washington       United States, California
# United States, West Virginia  United States, Pennsylvania
# United States, Wisconsin         United States, Wisconsin
# United States, Wyoming            United States, Colorado
#
#                                                      2007  \
# location
# Australia                                       Australia
# Belgium                                           Belgium
# Brazil                                            Belgium
# Canada                                             Canada
# Croatia                                           Belgium
# ...                                                   ...
# United States, Virginia         United States, California
# United States, Washington       United States, California
# United States, West Virginia  United States, Pennsylvania
# United States, Wisconsin         United States, Wisconsin
# United States, Wyoming            United States, Colorado
#
#                                                    2008  \
# location
# Australia                                     Australia
# Belgium                                         Belgium
# Brazil                                           Brazil
# Canada                                           Canada
# Croatia                                         Germany
# ...                                                 ...
# United States, Virginia       United States, California
# United States, Washington     United States, California
# United States, West Virginia  United States, California
# United States, Wisconsin       United States, Wisconsin
# United States, Wyoming          United States, Missouri
#
#                                                    2009  \
# location
# Australia                                     Australia
# Belgium                                         Belgium
# Brazil                                           Brazil
# Canada                                           Canada
# Croatia                                  Czech Republic
# ...                                                 ...
# United States, Virginia       United States, California
# United States, Washington     United States, California
# United States, West Virginia    United States, New York
# United States, Wisconsin       United States, Wisconsin
# United States, Wyoming        United States, California
#
#                                                    2010  \
# location
# Australia                                     Australia
# Belgium                                         Belgium
# Brazil                                           Brazil
# Canada                                           Canada
# Croatia                                         Germany
# ...                                                 ...
# United States, Virginia       United States, California
# United States, Washington     United States, California
# United States, West Virginia  United States, California
# United States, Wisconsin       United States, Wisconsin
# United States, Wyoming          United States, Colorado
#
#                                                    2011  \
# location
# Australia                                     Australia
# Belgium                                         Belgium
# Brazil                                           Brazil
# Canada                                           Canada
# Croatia                                         Germany
# ...                                                 ...
# United States, Virginia       United States, California
# United States, Washington     United States, California
# United States, West Virginia  United States, California
# United States, Wisconsin       United States, Wisconsin
# United States, Wyoming        United States, California
#
#                                                    2012  \
# location
# Australia                                     Australia
# Belgium                                         Belgium
# Brazil                                           Brazil
# Canada                                           Canada
# Croatia                                         Germany
# ...                                                 ...
# United States, Virginia       United States, California
# United States, Washington     United States, California
# United States, West Virginia  United States, California
# United States, Wisconsin       United States, Wisconsin
# United States, Wyoming        United States, California
#
#                                                    2013  \
# location
# Australia                                     Australia
# Belgium                                         Belgium
# Brazil                                           Brazil
# Canada                                           Canada
# Croatia                                         Germany
# ...                                                 ...
# United States, Virginia       United States, California
# United States, Washington     United States, California
# United States, West Virginia  United States, California
# United States, Wisconsin       United States, Wisconsin
# United States, Wyoming        United States, California
#
#                                                    2014  \
# location
# Australia                                     Australia
# Belgium                                         Belgium
# Brazil                                           Brazil
# Canada                                           Canada
# Croatia                                         Germany
# ...                                                 ...
# United States, Virginia         United States, Virginia
# United States, Washington     United States, California
# United States, West Virginia  United States, California
# United States, Wisconsin       United States, Wisconsin
# United States, Wyoming        United States, California
#
#                                                    2015  \
# location
# Australia                                     Australia
# Belgium                                         Belgium
# Brazil                                           Brazil
# Canada                                           Canada
# Croatia                                         Germany
# ...                                                 ...
# United States, Virginia         United States, Virginia
# United States, Washington     United States, Washington
# United States, West Virginia  United States, California
# United States, Wisconsin       United States, Wisconsin
# United States, Wyoming        United States, California
#
#                                                    2016  \
# location
# Australia                                     Australia
# Belgium                                         Belgium
# Brazil                                           Brazil
# Canada                                           Canada
# Croatia                                         Croatia
# ...                                                 ...
# United States, Virginia         United States, Virginia
# United States, Washington     United States, Washington
# United States, West Virginia  United States, California
# United States, Wisconsin       United States, Wisconsin
# United States, Wyoming          United States, Colorado
#
#                                                    2017
# location
# Australia                                     Australia
# Belgium                                         Belgium
# Brazil                                           Brazil
# Canada                                           Canada
# Croatia                                         Croatia
# ...                                                 ...
# United States, Virginia         United States, Virginia
# United States, Washington     United States, Washington
# United States, West Virginia        United States, Ohio
# United States, Wisconsin       United States, Wisconsin
# United States, Wyoming          United States, Colorado
#
# [71 rows x 12 columns]

# %% [markdown]
# ### *Rating-based brewery location preferences*

# %%
all_years_list = sorted(ratings['year'].unique())
bc_ratings_by_year = pd.DataFrame()
for year in all_years_list:
    location_bc = location_brewery_country_stats(ratings.copy(), users.copy(), breweries.copy(), year, loc_brewery_threshold = 20, rating_flag = True)
    location_bc_gb_loc = location_bc.groupby('location')
    idx_highest_rated = location_bc_gb_loc['z_score'].idxmax()
    highest_rated_bc_by_location = location_bc.loc[idx_highest_rated]
    highest_rated_bc_by_location = highest_rated_bc_by_location[['location', 'brewery_location']]
    highest_rated_bc_by_location.set_index('location', inplace=True)
    highest_rated_bc_by_location = highest_rated_bc_by_location.rename(columns={'brewery_location': str(year)})
    bc_ratings_by_year = pd.concat([bc_ratings_by_year, highest_rated_bc_by_location], axis=1)
    
bc_ratings_by_year
# Out:
#                                                     2006  \
# location
# Australia                      United States, California
# Belgium                        United States, California
# Brazil                                           Germany
# Canada                             United States, Alaska
# Croatia                                          Belgium
# ...                                                  ...
# United States, Virginia       United States, Connecticut
# United States, Washington     United States, Connecticut
# United States, West Virginia         United States, Ohio
# United States, Wisconsin       United States, New Jersey
# United States, Wyoming                           Belgium
#
#                                                     2007  \
# location
# Australia                        United States, Colorado
# Belgium                        United States, California
# Brazil                                            Canada
# Canada                                            Norway
# Croatia                                          Belgium
# ...                                                  ...
# United States, Virginia       United States, Connecticut
# United States, Washington                         Norway
# United States, West Virginia                     Belgium
# United States, Wisconsin                          Norway
# United States, Wyoming         United States, California
#
#                                                    2008  \
# location
# Australia                         United States, Oregon
# Belgium                         United States, Michigan
# Brazil                        United States, California
# Canada                                           Norway
# Croatia                                         Belgium
# ...                                                 ...
# United States, Virginia                          Norway
# United States, Washington                        Norway
# United States, West Virginia    United States, Michigan
# United States, Wisconsin                         Norway
# United States, Wyoming                          Belgium
#
#                                                 2009  \
# location
# Australia                                     Norway
# Belgium                       United States, Georgia
# Brazil                                       Belgium
# Canada                                        Norway
# Croatia                                      England
# ...                                              ...
# United States, Virginia                       Norway
# United States, Washington                     Norway
# United States, West Virginia                 Belgium
# United States, Wisconsin       United States, Alaska
# United States, Wyoming                       Belgium
#
#                                                    2010  \
# location
# Australia                                        Norway
# Belgium                           United States, Oregon
# Brazil                                          Belgium
# Canada                                           Norway
# Croatia                                        Scotland
# ...                                                 ...
# United States, Virginia        United States, Minnesota
# United States, Washington        United States, Indiana
# United States, West Virginia                    Belgium
# United States, Wisconsin                         Norway
# United States, Wyoming        United States, California
#
#                                                    2011  \
# location
# Australia                       United States, Michigan
# Belgium                                          Norway
# Brazil                        United States, California
# Canada                                           Norway
# Croatia                                          Sweden
# ...                                                 ...
# United States, Virginia           United States, Alaska
# United States, Washington                   Switzerland
# United States, West Virginia                    Belgium
# United States, Wisconsin                         Norway
# United States, Wyoming        United States, California
#
#                                                  2012  \
# location
# Australia                       United States, Alaska
# Belgium                       United States, Illinois
# Brazil                                        Belgium
# Canada                         United States, Indiana
# Croatia                                       Belgium
# ...                                               ...
# United States, Virginia         United States, Alaska
# United States, Washington                     Belgium
# United States, West Virginia  United States, Michigan
# United States, Wisconsin                       Norway
# United States, Wyoming                        Belgium
#
#                                                  2013                    2014  \
# location
# Australia                                      Norway  United States, Vermont
# Belgium                        United States, Vermont     United States, Iowa
# Brazil                         United States, Indiana  United States, Florida
# Canada                            United States, Iowa  United States, Vermont
# Croatia                                      Scotland                  Norway
# ...                                               ...                     ...
# United States, Virginia           United States, Iowa     United States, Iowa
# United States, Washington         United States, Iowa     United States, Iowa
# United States, West Virginia                  Belgium                 Belgium
# United States, Wisconsin          United States, Iowa     United States, Iowa
# United States, Wyoming        United States, Michigan  United States, Indiana
#
#                                                  2015  \
# location
# Australia                                      Norway
# Belgium                        United States, Vermont
# Brazil                        United States, Illinois
# Canada                        United States, Oklahoma
# Croatia                                        Norway
# ...                                               ...
# United States, Virginia                        Norway
# United States, Washington      United States, Vermont
# United States, West Virginia   United States, Indiana
# United States, Wisconsin          United States, Iowa
# United States, Wyoming            United States, Iowa
#
#                                                        2016  \
# location
# Australia                           United States, Oklahoma
# Belgium                       United States, South Carolina
# Brazil                               United States, Florida
# Canada                                  United States, Iowa
# Croatia                                              Norway
# ...                                                     ...
# United States, Virginia                         Switzerland
# United States, Washington               United States, Iowa
# United States, West Virginia                        Belgium
# United States, Wisconsin                United States, Iowa
# United States, Wyoming                              England
#
#                                                       2017
# location
# Australia                     United States, Massachusetts
# Belgium                                United States, Ohio
# Brazil                        United States, Massachusetts
# Canada                             United States, Oklahoma
# Croatia                              United States, Oregon
# ...                                                    ...
# United States, Virginia            United States, Oklahoma
# United States, Washington           United States, Wyoming
# United States, West Virginia         United States, Oregon
# United States, Wisconsin               United States, Iowa
# United States, Wyoming                United States, Idaho
#
# [71 rows x 12 columns]

# %% [markdown]
# ## *Extracting global beer preferences for each year*

# %% [markdown]
# Now we try to find the global beer preferences for each year. Simply looking at the total number of ratings and their distribution in that year would not represent the preference of the whole world since the locations with high populations heavily dominate the aggregated results. Therefore, we needed a way to aggregate the beer preferences coming from the individual locations at that year. We did not want to do this simply by finding the beer style or brewery location that was declared as the preferred one in the highest number of locations. This kind of approach would result in each location giving all their 'vote' only to their 'most' preferred beer style or brewery location, their 'second' or 'third' preferred ones would not receive any 'vote' no matter how close they are to the 'most' preferred one. This would throw away a significant amount of preference information available for each location.
#
# Instead, we came up with a much more thoughtful and interesting approach. If the Eurovision Song Contest can do it, so can we! In the Eurovision Song Contest, each country gives points to their top 10 favorite songs. The song that gets the highest number of points in total is the winner of the year. We decided to do something similar. For each location, we assign points to their top 10 favorite beer styles or brewery locations. The beer style or brewery location that gets the highest number of points wins the contest. The points are assigned as follows: 12 points for the most preferred beer style or brewery location, 10 points for the second most preferred one, 8 points for the third most preferred one, and so on, the exact rating system used in the contest. This way, we obtain a better representation of the beer preferences of the whole globe.
#
# Below, we apply the above-given approach to extract the global beer preferences for each year. Note that we normally treat each U.S. state as a separate location. However, for the global beer preference extraction, we treat the whole U.S. as a single location or otherwise U.S. would have too many votes in the contest. Therefore, our 'location_style_stats()' and 'location_brewery_country_stats()' functions have a boolean argument called 'global_flag' and if it is set to True, it replaces all the U.S. state names and replace them all with the name 'United States' before it begins with the point calculations. Furthermore, we provide not only the top 1 but top 10 preferences for each year with their collected points since this information will be used in our bar chart race visualizations in the website!

# %% [markdown]
# ### *Popularity-based global beer style preferences*

# %%
all_years_list = sorted(ratings['year'].unique())
global_style_popularity_points_by_year = pd.DataFrame()
points = [12, 10, 8, 7, 6, 5, 4, 3, 2, 1]
for year in all_years_list:
    style_popularity_points_dict = {key: 0 for key in ratings['style'].unique().tolist()}
    location_style = location_style_stats(ratings.copy(), users.copy(), year, loc_style_threshold = 10, rating_flag = False, global_flag = True)
    location_style_groupedby_loc = location_style.groupby('location')
    idx_10_most_popular = location_style_groupedby_loc['popularity_percentage'].nlargest(10).index.get_level_values(1)
    most_popular_styles_by_location = location_style.loc[idx_10_most_popular]
    
    point_idx = 0
    prev_location = most_popular_styles_by_location.iloc[0]['location']
    for index, row in most_popular_styles_by_location.iterrows():
        location = row['location']
        if location != prev_location:
            point_idx = 0
            prev_location = location
        style_popularity_points_dict[row['style']] += points[point_idx]
        point_idx += 1
    global_style_popularity_points_by_year[str(year)] = style_popularity_points_dict

global_style_popularities_by_year = global_style_popularity_points_by_year.apply(lambda x: x.nlargest(10).index.tolist()).T
global_style_popularities_by_year_points = global_style_popularity_points_by_year.apply(lambda x: x.nlargest(10).tolist()).T
tuple_list = {column: list(zip(global_style_popularities_by_year[column], global_style_popularities_by_year_points[column])) for column in global_style_popularities_by_year.columns}
global_style_popularities_by_year = pd.DataFrame(tuple_list, index = global_style_popularities_by_year.index)

global_style_popularities_by_year.columns = ['1st Most Popular', '2nd Most Popular', '3rd Most Popular', '4th Most Popular', '5th Most Popular', '6th Most Popular', '7th Most Popular', '8th Most Popular', '9th Most Popular', '10th Most Popular']
global_style_popularities_by_year.index.name = 'Year'
global_style_popularities_by_year
# Out:
#                  1st Most Popular             2nd Most Popular  \
# Year
# 2006              (Pilsener, 117)            (Pale Lager, 106)
# 2007            (Pale Lager, 118)              (Pilsener, 102)
# 2008            (Pale Lager, 108)              (Pilsener, 100)
# 2009              (Pilsener, 108)   (India Pale Ale (IPA), 82)
# 2010            (Pale Lager, 136)     (Belgian Strong Ale, 81)
# 2011            (Pale Lager, 134)  (India Pale Ale (IPA), 100)
# 2012  (India Pale Ale (IPA), 112)            (Pale Lager, 104)
# 2013  (India Pale Ale (IPA), 116)     (American Pale Ale, 109)
# 2014  (India Pale Ale (IPA), 154)     (American Pale Ale, 110)
# 2015  (India Pale Ale (IPA), 132)     (American Pale Ale, 110)
# 2016  (India Pale Ale (IPA), 144)        (Imperial Stout, 105)
# 2017  (India Pale Ale (IPA), 132)        (Imperial Stout, 107)
#
#               3rd Most Popular            4th Most Popular  \
# Year
# 2006  (Belgian Strong Ale, 82)     (German Hefeweizen, 69)
# 2007  (Belgian Strong Ale, 78)  (Golden Ale/Blond Ale, 74)
# 2008  (Belgian Strong Ale, 86)        (Imperial Stout, 75)
# 2009          (Pale Lager, 80)    (Belgian Strong Ale, 64)
# 2010            (Pilsener, 78)  (India Pale Ale (IPA), 76)
# 2011            (Pilsener, 93)        (Imperial Stout, 85)
# 2012      (Imperial Stout, 93)     (American Pale Ale, 88)
# 2013          (Pale Lager, 95)        (Imperial Stout, 93)
# 2014          (Pale Lager, 99)        (Imperial Stout, 79)
# 2015     (Imperial Stout, 106)                (Saison, 94)
# 2016  (American Pale Ale, 102)            (Pale Lager, 72)
# 2017   (American Pale Ale, 99)                (Saison, 81)
#
#                 5th Most Popular            6th Most Popular  \
# Year
# 2006  (Golden Ale/Blond Ale, 66)           (Belgian Ale, 63)
# 2007                (Bitter, 66)                (Porter, 66)
# 2008  (Golden Ale/Blond Ale, 71)  (India Pale Ale (IPA), 68)
# 2009                (Porter, 62)           (Belgian Ale, 62)
# 2010        (Imperial Stout, 76)                (Porter, 66)
# 2011    (Belgian Strong Ale, 84)                (Porter, 66)
# 2012    (Belgian Strong Ale, 84)              (Pilsener, 78)
# 2013              (Pilsener, 83)    (Belgian Strong Ale, 77)
# 2014    (Belgian Strong Ale, 74)                (Porter, 69)
# 2015            (Pale Lager, 87)    (Belgian Strong Ale, 77)
# 2016          (Imperial IPA, 69)    (Belgian Strong Ale, 67)
# 2017              (Pilsener, 76)                (Porter, 76)
#
#                 7th Most Popular            8th Most Popular  \
# Year
# 2006    (Premium Bitter/ESB, 62)                (Porter, 58)
# 2007     (German Hefeweizen, 66)  (India Pale Ale (IPA), 65)
# 2008                (Bitter, 66)                (Porter, 63)
# 2009        (Imperial Stout, 61)  (Golden Ale/Blond Ale, 53)
# 2010  (Golden Ale/Blond Ale, 64)     (German Hefeweizen, 56)
# 2011  (Golden Ale/Blond Ale, 65)     (German Hefeweizen, 64)
# 2012           (Belgian Ale, 78)                (Porter, 77)
# 2013                (Porter, 67)  (Golden Ale/Blond Ale, 59)
# 2014  (Golden Ale/Blond Ale, 64)                (Saison, 63)
# 2015  (Golden Ale/Blond Ale, 69)              (Pilsener, 65)
# 2016                (Saison, 66)                (Porter, 63)
# 2017         (Sour/Wild Ale, 76)  (Golden Ale/Blond Ale, 71)
#
#               9th Most Popular           10th Most Popular
# Year
# 2006              (Bitter, 56)          (Dunkel/Tmavý, 52)
# 2007         (Belgian Ale, 64)            (Fruit Beer, 48)
# 2008         (Belgian Ale, 60)            (Fruit Beer, 55)
# 2009  (Premium Bitter/ESB, 49)     (American Pale Ale, 48)
# 2010              (Bitter, 51)          (Imperial IPA, 50)
# 2011              (Bitter, 60)           (Belgian Ale, 59)
# 2012        (Imperial IPA, 58)  (Golden Ale/Blond Ale, 51)
# 2013         (Belgian Ale, 58)          (Imperial IPA, 50)
# 2014         (Belgian Ale, 63)              (Pilsener, 59)
# 2015        (Imperial IPA, 60)           (Belgian Ale, 57)
# 2016            (Pilsener, 62)         (Sour/Wild Ale, 59)
# 2017          (Pale Lager, 65)    (Belgian Strong Ale, 63)

# %% [markdown]
# ### *Rating-based global beer style preferences*

# %%
all_years_list = sorted(ratings['year'].unique())
global_style_rating_points_by_year = pd.DataFrame()
points = [12, 10, 8, 7, 6, 5, 4, 3, 2, 1]
for year in all_years_list:
    style_rating_points_dict = {key: 0 for key in ratings['style'].unique().tolist()}
    location_style = location_style_stats(ratings.copy(), users.copy(), year, loc_style_threshold = 10, rating_flag = True, global_flag = True)
    location_style_groupedby_loc = location_style.groupby('location')
    idx_10_highest_rated = location_style_groupedby_loc['z_score'].nlargest(10).index.get_level_values(1)
    highest_rated_styles_by_location = location_style.loc[idx_10_highest_rated]
    
    point_idx = 0
    prev_location = highest_rated_styles_by_location.iloc[0]['location']
    for index, row in highest_rated_styles_by_location.iterrows():
        location = row['location']
        if location != prev_location:
            point_idx = 0
            prev_location = location
        style_rating_points_dict[row['style']] += points[point_idx]
        point_idx += 1
    global_style_rating_points_by_year[str(year)] = style_rating_points_dict

global_style_highest_rated_by_year = global_style_rating_points_by_year.apply(lambda x: x.nlargest(10).index.tolist()).T
global_style_highest_rated_by_year_points = global_style_rating_points_by_year.apply(lambda x: x.nlargest(10).tolist()).T

tuple_list = {column: list(zip(global_style_highest_rated_by_year[column], global_style_highest_rated_by_year_points[column])) for column in global_style_highest_rated_by_year.columns}
global_style_highest_rated_by_year = pd.DataFrame(tuple_list, index = global_style_highest_rated_by_year.index)

global_style_highest_rated_by_year.columns = ['1st Highest Rated', '2nd Highest Rated', '3rd Highest Rated', '4th Highest Rated', '5th Highest Rated', '6th Highest Rated', '7th Highest Rated', '8th Highest Rated', '9th Highest Rated', '10th Highest Rated']
global_style_highest_rated_by_year.index.name = 'Year'
global_style_highest_rated_by_year
# Out:
#           1st Highest Rated             2nd Highest Rated  \
# Year
# 2006  (Imperial Stout, 112)          (Abt/Quadrupel, 111)
# 2007   (Abt/Quadrupel, 158)         (Imperial Stout, 154)
# 2008  (Imperial Stout, 204)          (Abt/Quadrupel, 148)
# 2009  (Imperial Stout, 188)          (Abt/Quadrupel, 141)
# 2010  (Imperial Stout, 204)          (Abt/Quadrupel, 156)
# 2011  (Imperial Stout, 196)          (Abt/Quadrupel, 152)
# 2012  (Imperial Stout, 193)          (Abt/Quadrupel, 179)
# 2013  (Imperial Stout, 213)          (Abt/Quadrupel, 209)
# 2014  (Imperial Stout, 244)          (Abt/Quadrupel, 185)
# 2015  (Imperial Stout, 239)          (Abt/Quadrupel, 164)
# 2016  (Imperial Stout, 220)          (Abt/Quadrupel, 167)
# 2017  (Imperial Stout, 220)  (Lambic Style - Gueuze, 148)
#
#                  3rd Highest Rated               4th Highest Rated  \
# Year
# 2006     (Belgian Strong Ale, 108)              (Imperial IPA, 82)
# 2007     (Belgian Strong Ale, 110)              (Imperial IPA, 85)
# 2008           (Imperial IPA, 119)        (Belgian Strong Ale, 99)
# 2009           (Imperial IPA, 100)            (Sour Red/Brown, 79)
# 2010            (Imperial IPA, 81)  (Lambic Style - Unblended, 81)
# 2011           (Imperial IPA, 132)     (Lambic Style - Gueuze, 93)
# 2012           (Imperial IPA, 137)    (Lambic Style - Gueuze, 118)
# 2013           (Imperial IPA, 106)    (Lambic Style - Gueuze, 103)
# 2014  (Lambic Style - Gueuze, 117)             (Imperial IPA, 113)
# 2015  (Lambic Style - Gueuze, 163)             (Imperial IPA, 103)
# 2016  (Lambic Style - Gueuze, 162)             (Imperial IPA, 112)
# 2017          (Abt/Quadrupel, 144)             (Imperial IPA, 111)
#
#                    5th Highest Rated           6th Highest Rated  \
# Year
# 2006     (Lambic Style - Gueuze, 57)         (Baltic Porter, 47)
# 2007               (Barley Wine, 57)        (Sour Red/Brown, 52)
# 2008             (Sour/Wild Ale, 79)           (Barley Wine, 72)
# 2009               (Barley Wine, 72)    (Belgian Strong Ale, 65)
# 2010        (Belgian Strong Ale, 63)  (American Strong Ale , 63)
# 2011  (Lambic Style - Unblended, 67)  (American Strong Ale , 58)
# 2012                 (Black IPA, 72)  (American Strong Ale , 72)
# 2013      (American Strong Ale , 73)               (Eisbock, 67)
# 2014      (American Strong Ale , 88)           (Barley Wine, 70)
# 2015      (Lambic Style - Fruit, 85)           (Barley Wine, 78)
# 2016  (Lambic Style - Unblended, 89)        (Sour Red/Brown, 77)
# 2017     (Lambic Style - Fruit, 101)        (Sour Red/Brown, 75)
#
#                    7th Highest Rated               8th Highest Rated  \
# Year
# 2006              (Abbey Tripel, 39)             (Sour/Wild Ale, 38)
# 2007                    (Porter, 51)      (American Strong Ale , 50)
# 2008     (Lambic Style - Gueuze, 55)              (Abbey Tripel, 52)
# 2009             (Sour/Wild Ale, 58)     (Lambic Style - Gueuze, 58)
# 2010            (Sour Red/Brown, 52)     (Lambic Style - Gueuze, 49)
# 2011               (Barley Wine, 56)        (Belgian Strong Ale, 48)
# 2012             (Sour/Wild Ale, 60)               (Barley Wine, 53)
# 2013                 (Black IPA, 58)             (Sour/Wild Ale, 53)
# 2014                 (Black IPA, 60)  (Lambic Style - Unblended, 60)
# 2015  (Lambic Style - Unblended, 74)      (American Strong Ale , 57)
# 2016      (Lambic Style - Fruit, 70)      (American Strong Ale , 62)
# 2017      (American Strong Ale , 65)               (Barley Wine, 60)
#
#                    9th Highest Rated              10th Highest Rated
# Year
# 2006               (Belgian Ale, 37)      (American Strong Ale , 37)
# 2007             (Sour/Wild Ale, 40)     (Lambic Style - Gueuze, 40)
# 2008      (India Pale Ale (IPA), 45)             (Baltic Porter, 45)
# 2009      (American Strong Ale , 51)      (India Pale Ale (IPA), 45)
# 2010              (Abbey Tripel, 47)                 (Black IPA, 45)
# 2011             (Sour/Wild Ale, 47)                 (Black IPA, 43)
# 2012            (Sour Red/Brown, 48)  (Lambic Style - Unblended, 46)
# 2013               (Barley Wine, 48)  (Lambic Style - Unblended, 48)
# 2014                   (Eisbock, 58)             (Sour/Wild Ale, 57)
# 2015               (Weizen Bock, 44)                 (Black IPA, 43)
# 2016               (Barley Wine, 59)             (Baltic Porter, 44)
# 2017  (Lambic Style - Unblended, 47)             (Baltic Porter, 43)

# %% [markdown]
# ### *Popularity-based global brewery location preferences*

# %%
all_years_list = sorted(ratings['year'].unique())
global_brewery_popularity_points_by_year = pd.DataFrame()
points = [12, 10, 8, 7, 6, 5, 4, 3, 2, 1]
for year in all_years_list:
    brewery_popularity_points_dict = {key: 0 for key in breweries['location'].unique().tolist()}
    location_bc = location_brewery_country_stats(ratings.copy(), users.copy(), breweries.copy(), year, loc_brewery_threshold = 20, rating_flag = False, global_flag = True)
    location_bc_groupedby_loc = location_bc.groupby('location')
    idx_10_most_popular = location_bc_groupedby_loc['popularity_percentage'].nlargest(10).index.get_level_values(1)
    most_popular_breweries_by_location = location_bc.loc[idx_10_most_popular]
    
    point_idx = 0
    prev_location = most_popular_breweries_by_location.iloc[0]['location']
    for index, row in most_popular_breweries_by_location.iterrows():
        location = row['location']
        if location != prev_location:
            point_idx = 0
            prev_location = location
        brewery_popularity_points_dict[row['brewery_location']] += points[point_idx]
        point_idx += 1
    global_brewery_popularity_points_by_year[str(year)] = brewery_popularity_points_dict

global_brewery_popularities_by_year = global_brewery_popularity_points_by_year.apply(lambda x: x.nlargest(10).index.tolist()).T
global_brewery_popularities_by_year_points = global_brewery_popularity_points_by_year.apply(lambda x: x.nlargest(10).tolist()).T

tuple_list = {column: list(zip(global_brewery_popularities_by_year[column], global_brewery_popularities_by_year_points[column])) for column in global_brewery_popularities_by_year.columns}
global_brewery_popularities_by_year = pd.DataFrame(tuple_list, index = global_brewery_popularities_by_year.index)

global_brewery_popularities_by_year.columns = ['1st Most Popular', '2nd Most Popular', '3rd Most Popular', '4th Most Popular', '5th Most Popular', '6th Most Popular', '7th Most Popular', '8th Most Popular', '9th Most Popular', '10th Most Popular']
global_brewery_popularities_by_year.index.name = 'Year'
global_brewery_popularities_by_year
# Out:
#                      1st Most Popular                 2nd Most Popular  \
# Year
# 2006                   (Belgium, 104)                    (England, 90)
# 2007                    (Germany, 90)                    (Belgium, 80)
# 2008                    (England, 98)                    (Germany, 86)
# 2009                    (Germany, 80)  (United States, California, 68)
# 2010                    (Belgium, 76)  (United States, California, 74)
# 2011                   (Belgium, 100)  (United States, California, 74)
# 2012                    (Belgium, 86)                    (Germany, 84)
# 2013                    (Belgium, 86)                    (Germany, 78)
# 2014                    (Belgium, 76)                    (Germany, 62)
# 2015  (United States, California, 76)                    (Belgium, 76)
# 2016                    (Belgium, 84)  (United States, California, 82)
# 2017                    (England, 74)                    (Belgium, 70)
#
#                      3rd Most Popular               4th Most Popular  \
# Year
# 2006                    (Germany, 82)              (Netherlands, 53)
# 2007                    (England, 78)                  (Denmark, 57)
# 2008                    (Belgium, 80)                  (Denmark, 70)
# 2009    (United States, New York, 60)                  (Belgium, 58)
# 2010                    (Germany, 68)                  (England, 68)
# 2011                    (Germany, 73)                  (England, 60)
# 2012  (United States, California, 69)                  (England, 58)
# 2013  (United States, California, 62)                  (Denmark, 57)
# 2014  (United States, California, 61)                  (Denmark, 55)
# 2015                    (Germany, 65)  (United States, New York, 54)
# 2016                    (Germany, 71)                  (England, 56)
# 2017  (United States, California, 57)  (United States, New York, 55)
#
#                      5th Most Popular               6th Most Popular  \
# Year
# 2006                   (Scotland, 51)           (Czech Republic, 50)
# 2007  (United States, California, 57)                   (Sweden, 49)
# 2008  (United States, California, 57)              (Netherlands, 50)
# 2009                    (England, 56)           (Czech Republic, 51)
# 2010    (United States, New York, 54)           (Czech Republic, 45)
# 2011             (Czech Republic, 51)  (United States, New York, 50)
# 2012                    (Denmark, 57)  (United States, New York, 57)
# 2013                    (England, 48)  (United States, New York, 46)
# 2014             (Czech Republic, 54)                  (England, 54)
# 2015                    (England, 54)    (United States, Oregon, 45)
# 2016                    (Denmark, 55)                   (Sweden, 52)
# 2017                    (Germany, 53)                   (Sweden, 49)
#
#                      7th Most Popular             8th Most Popular  \
# Year
# 2006  (United States, California, 45)                 (France, 40)
# 2007             (Czech Republic, 45)            (Netherlands, 45)
# 2008    (United States, New York, 44)         (Czech Republic, 43)
# 2009                    (Denmark, 45)                 (Sweden, 42)
# 2010                     (Norway, 44)                (Denmark, 42)
# 2011                    (Denmark, 46)               (Scotland, 45)
# 2012                (Netherlands, 46)               (Scotland, 43)
# 2013                     (Norway, 45)  (United States, Oregon, 45)
# 2014    (United States, New York, 44)               (Scotland, 42)
# 2015                    (Denmark, 44)         (Czech Republic, 44)
# 2016             (Czech Republic, 48)  (United States, Oregon, 46)
# 2017                    (Denmark, 47)         (Czech Republic, 47)
#
#                    9th Most Popular              10th Most Popular
# Year
# 2006                  (Denmark, 36)                   (Sweden, 35)
# 2007                 (Scotland, 44)  (United States, New York, 43)
# 2008  (United States, Colorado, 43)                 (Scotland, 39)
# 2009  (United States, Maryland, 38)                 (Scotland, 37)
# 2010  (United States, Colorado, 39)                   (Canada, 36)
# 2011  (United States, Maryland, 41)              (Netherlands, 40)
# 2012                    (Japan, 34)           (Czech Republic, 34)
# 2013                 (Scotland, 41)           (Czech Republic, 40)
# 2014                    (Japan, 40)    (United States, Oregon, 39)
# 2015                   (Sweden, 43)                 (Scotland, 41)
# 2016  (United States, New York, 38)  (United States, Colorado, 38)
# 2017              (Netherlands, 37)                 (Scotland, 34)

# %% [markdown]
# ### *Rating-based global brewery location preferences*

# %%
all_years_list = sorted(ratings['year'].unique())
global_brewery_rating_points_by_year = pd.DataFrame()
points = [12, 10, 8, 7, 6, 5, 4, 3, 2, 1]
for year in all_years_list:
    brewery_rating_points_dict = {key: 0 for key in breweries['location'].unique().tolist()}
    location_bc = location_brewery_country_stats(ratings.copy(), users.copy(), breweries.copy(), year, loc_brewery_threshold = 20, rating_flag = True, global_flag = True)
    location_bc_groupedby_loc = location_bc.groupby('location')
    idx_10_highest_rated = location_bc_groupedby_loc['z_score'].nlargest(10).index.get_level_values(1)
    highest_rated_breweries_by_location = location_bc.loc[idx_10_highest_rated]
    
    point_idx = 0
    prev_location = highest_rated_breweries_by_location.iloc[0]['location']
    for index, row in highest_rated_breweries_by_location.iterrows():
        location = row['location']
        if location != prev_location:
            point_idx = 0
            prev_location = location
        brewery_rating_points_dict[row['brewery_location']] += points[point_idx]
        point_idx += 1
    global_brewery_rating_points_by_year[str(year)] = brewery_rating_points_dict

global_brewery_highest_rated_by_year = global_brewery_rating_points_by_year.apply(lambda x: x.nlargest(10).index.tolist()).T
global_brewery_highest_rated_by_year_points = global_brewery_rating_points_by_year.apply(lambda x: x.nlargest(10).tolist()).T

tuple_list = {column: list(zip(global_brewery_highest_rated_by_year[column], global_brewery_highest_rated_by_year_points[column])) for column in global_brewery_highest_rated_by_year.columns}
global_brewery_highest_rated_by_year = pd.DataFrame(tuple_list, index = global_brewery_highest_rated_by_year.index)

global_brewery_highest_rated_by_year.columns = ['1st Highest Rated', '2nd Highest Rated', '3rd Highest Rated', '4th Highest Rated', '5th Highest Rated', '6th Highest Rated', '7th Highest Rated', '8th Highest Rated', '9th Highest Rated', '10th Highest Rated']
global_brewery_highest_rated_by_year.index.name = 'Year'
global_brewery_highest_rated_by_year
# Out:
#                      1st Highest Rated                 2nd Highest Rated  \
# Year
# 2006                    (Belgium, 179)                     (Germany, 97)
# 2007                    (Belgium, 178)  (United States, California, 104)
# 2008                    (Belgium, 182)  (United States, California, 129)
# 2009  (United States, California, 178)                    (Belgium, 130)
# 2010  (United States, California, 134)                    (Belgium, 130)
# 2011  (United States, California, 152)                    (Belgium, 136)
# 2012  (United States, California, 128)                    (Belgium, 113)
# 2013  (United States, California, 136)       (United States, Alaska, 98)
# 2014  (United States, California, 117)     (United States, Vermont, 105)
# 2015    (United States, Oklahoma, 137)     (United States, Vermont, 112)
# 2016    (United States, Oklahoma, 120)      (United States, Vermont, 95)
# 2017    (United States, Oklahoma, 107)      (United States, Vermont, 96)
#
#                      3rd Highest Rated                   4th Highest Rated  \
# Year
# 2006   (United States, California, 79)                       (England, 79)
# 2007                     (Germany, 88)                       (England, 86)
# 2008                     (England, 93)         (United States, Oregon, 86)
# 2009       (United States, Oregon, 81)                        (Norway, 72)
# 2010                     (Norway, 110)         (United States, Oregon, 80)
# 2011                     (Norway, 115)         (United States, Oregon, 77)
# 2012                      (Norway, 98)           (United States, Ohio, 94)
# 2013                      (Norway, 93)                       (Belgium, 87)
# 2014    (United States, Oklahoma, 101)                        (Norway, 85)
# 2015  (United States, California, 101)                       (Belgium, 86)
# 2016   (United States, California, 89)  (United States, Massachusetts, 75)
# 2017         (United States, Ohio, 88)  (United States, Massachusetts, 86)
#
#                     5th Highest Rated                    6th Highest Rated  \
# Year
# 2006      (United States, Oregon, 65)                       (Scotland, 61)
# 2007                     (Canada, 65)                       (Scotland, 62)
# 2008                    (Germany, 72)        (United States, Colorado, 57)
# 2009                    (England, 71)        (United States, Michigan, 59)
# 2010                    (England, 78)            (United States, Ohio, 75)
# 2011    (United States, New York, 64)        (United States, Michigan, 60)
# 2012      (United States, Alaska, 77)        (United States, Michigan, 73)
# 2013     (United States, Vermont, 86)            (United States, Ohio, 65)
# 2014        (United States, Ohio, 85)          (United States, Oregon, 78)
# 2015                     (Norway, 81)            (United States, Iowa, 56)
# 2016                    (Belgium, 70)  (United States, South Carolina, 68)
# 2017  (United States, California, 70)                        (Belgium, 62)
#
#                         7th Highest Rated              8th Highest Rated  \
# Year
# 2006        (United States, Colorado, 43)                  (Denmark, 38)
# 2007        (United States, New York, 54)  (United States, Colorado, 53)
# 2008            (United States, Ohio, 53)                   (Canada, 52)
# 2009            (United States, Ohio, 58)                 (Scotland, 44)
# 2010        (United States, Michigan, 62)  (United States, New York, 59)
# 2011                        (England, 56)      (United States, Ohio, 46)
# 2012          (United States, Oregon, 70)  (United States, New York, 60)
# 2013  (United States, South Carolina, 58)  (United States, New York, 47)
# 2014                        (Belgium, 73)  (United States, Illinois, 70)
# 2015  (United States, South Carolina, 49)      (United States, Ohio, 48)
# 2016            (United States, Ohio, 64)      (United States, Iowa, 62)
# 2017                         (Norway, 55)   (United States, Florida, 47)
#
#                         9th Highest Rated                  10th Highest Rated
# Year
# 2006                         (Canada, 34)       (United States, New York, 28)
# 2007                         (Norway, 47)           (United States, Ohio, 30)
# 2008                       (Scotland, 47)       (United States, Michigan, 44)
# 2009        (United States, Colorado, 43)                        (Canada, 42)
# 2010                        (Germany, 49)                      (Scotland, 44)
# 2011        (United States, Colorado, 41)        (United States, Vermont, 40)
# 2012        (United States, Illinois, 59)        (United States, Vermont, 58)
# 2013          (United States, Oregon, 47)       (United States, Oklahoma, 47)
# 2014          (United States, Alaska, 54)       (United States, Michigan, 54)
# 2015        (United States, Michigan, 45)         (United States, Alaska, 44)
# 2016                         (Norway, 46)  (United States, New Hampshire, 46)
# 2017  (United States, South Carolina, 40)   (United States, Pennsylvania, 38)

# %% [markdown]
# ## *Clustering the beer styles and brewery locations and restating the beer preferences accordingly*

# %% [markdown]
# The individual beer preferences of each location were provided before for each year. However, a significant part of the project is to see how the beer preferences evolve and spread vs. time in the world. Simply looking at the tables is not the right way to extract such an information. Therefore, we would like to assign each preference (style or brewery location) to a unique color and color the locations on the world map based on their preferences in that year and update the colors on the world map versus time. However, we have 73 beer styles and over 300 brewery locations in our dataset and we cannot possibly assign each of them to a unique and meaningful color. Even if we could, it would be too much work for the reader to identify the right color from the legend. Therefore, we cluster the preferences (beer styles and brewery locations) under broader categories such that we have now only 14 beer style categories and 8 brewery location categories. The beer style clustering was performed after an extensive research on the web and the brewery location clustering was performed based on the continents. The dictionaries used for the clusterings can be found below.

# %%
beer_styles_dict = {'Wheat Beer': ['German Hefeweizen', 'Dunkelweizen', 'Witbier', 'Berliner Weisse', 'Grodziskie/Gose/Lichtenhainer', 'German Kristallweizen', 'Wheat Ale'], 'Lambic & Sour Ale': ['Sour/Wild Ale', 'Fruit Beer', 'Lambic Style - Fruit', 'Lambic Style - Gueuze', 'Lambic Style - Unblended', 'Lambic Style - Faro', 'Sour Red/Brown'], 'Belgian Ale': ['Abbey Tripel', 'Belgian Ale', 'Belgian Strong Ale', 'Abbey Dubbel', 'Abt/Quadrupel', 'Bière de Garde', 'Saison'], 'Pale Ale': ['Golden Ale/Blond Ale', 'American Pale Ale', 'India Pale Ale (IPA)', 'Black IPA', 'Amber Ale', 'Imperial IPA', 'Irish Ale'], 'Bitter': ['Bitter', 'Premium Bitter/ESB'], 'Scottish Ale': ['Scotch Ale', 'Scottish Ale'], 'Brown Ale': ['Mild Ale', 'Brown Ale', 'American Strong Ale ', 'English Strong Ale', 'Old Ale'], 'Porter': ['Porter', 'Baltic Porter'], 'Stout': ['Stout', 'Sweet Stout', 'Dry Stout', 'Foreign Stout', 'Imperial Stout'], 'Pilsener': ['Pilsener', 'Dortmunder/Helles'], 'Lager': ['Imperial Pils/Strong Pale Lager', 'Pale Lager', 'Amber Lager/Vienna', 'Schwarzbier', 'Altbier', 'Zwickel/Keller/Landbier', 'Dunkel/Tmavý'], 'Bock': ['Doppelbock', 'Dunkler Bock', 'Eisbock', 'Heller Bock', 'Weizen Bock'], 'American Special': ['Cream Ale', 'California Common'], 'Alternative/Traditional': ['Sahti/Gotlandsdricke/Koduõlu', 'Mead', 'Malt Liquor', 'Low Alcohol', 'Specialty Grain', 'Spice/Herb/Vegetable', 'Oktoberfest/Märzen', 'Smoked', 'Barley Wine', 'Kölsch', 'Traditional Ale']}

inverted_beer_styles_dict = {}

for key, values in beer_styles_dict.items():
    for value in values:
        inverted_beer_styles_dict[value] = key

# %%
location_list_1 = pd.unique(bc_popularities_by_year.values.flatten())
location_list_2 = pd.unique(bc_ratings_by_year.values.flatten())
location_set = set(location_list_1.tolist() + location_list_2.tolist())
us_locations = [location for location in list(location_set) if 'United States' in location]
location_dict = {'Northern Europe': ['Denmark', 'Estonia', 'Finland', 'Iceland', 'Norway', 'Sweden'], 'Central/Western Europe': ['France', 'Germany', 'Ireland', 'Netherlands', 'Belgium', 'Switzerland', 'Czech Republic'], 'Southern Europe': ['Italy', 'Spain', 'Croatia'], 'Eastern Europe': ['Poland', 'Russia'], 'United Kingdom': ['England', 'Scotland', 'Northern Ireland'], 'North America': us_locations + ['Canada'], 'Central and South America': ['Brazil', 'Trinidad & Tobago'], 'Oceania': ['Australia', 'New Zealand']}

inverted_location_dict = {}

for key, values in location_dict.items():
    for value in values:
        inverted_location_dict[value] = key

# %% [markdown]
# ### *Popularity-based beer style preferences - Clustered*

# %%
style_popularities_by_year_clustered = style_popularities_by_year.replace(inverted_beer_styles_dict)
style_popularities_by_year_clustered
# Out:
#                                      2006         2007         2008  \
# location
# Australia                           Lager        Lager        Lager
# Belgium                       Belgian Ale  Belgian Ale  Belgian Ale
# Brazil                              Lager        Lager        Lager
# Canada                              Lager        Lager        Lager
# Croatia                             Lager        Lager        Lager
# ...                                   ...          ...          ...
# United States, Virginia          Pale Ale     Pale Ale     Pale Ale
# United States, Washington        Pale Ale     Pale Ale     Pale Ale
# United States, West Virginia     Pale Ale        Lager     Pale Ale
# United States, Wisconsin         Pale Ale     Pale Ale     Pale Ale
# United States, Wyoming           Pale Ale     Pale Ale        Lager
#
#                                      2009         2010         2011  \
# location
# Australia                           Lager        Lager        Lager
# Belgium                       Belgian Ale  Belgian Ale  Belgian Ale
# Brazil                              Lager        Lager        Lager
# Canada                              Lager        Lager        Lager
# Croatia                             Lager     Pilsener        Lager
# ...                                   ...          ...          ...
# United States, Virginia          Pale Ale     Pale Ale     Pale Ale
# United States, Washington        Pale Ale     Pale Ale     Pale Ale
# United States, West Virginia     Pale Ale     Pale Ale     Pale Ale
# United States, Wisconsin         Pale Ale     Pale Ale     Pale Ale
# United States, Wyoming              Lager        Lager     Pale Ale
#
#                                      2012         2013         2014  \
# location
# Australia                           Lager     Pale Ale     Pale Ale
# Belgium                       Belgian Ale  Belgian Ale  Belgian Ale
# Brazil                              Lager        Lager        Lager
# Canada                           Pale Ale        Lager     Pale Ale
# Croatia                             Lager        Lager        Lager
# ...                                   ...          ...          ...
# United States, Virginia          Pale Ale     Pale Ale     Pale Ale
# United States, Washington        Pale Ale     Pale Ale     Pale Ale
# United States, West Virginia     Pale Ale     Pale Ale     Pale Ale
# United States, Wisconsin         Pale Ale        Stout        Stout
# United States, Wyoming              Stout        Stout     Pale Ale
#
#                                      2015         2016               2017
# location
# Australia                        Pale Ale     Pale Ale           Pale Ale
# Belgium                       Belgian Ale  Belgian Ale              Stout
# Brazil                              Lager        Lager              Lager
# Canada                        Belgian Ale  Belgian Ale  Lambic & Sour Ale
# Croatia                             Lager        Lager              Lager
# ...                                   ...          ...                ...
# United States, Virginia          Pale Ale     Pale Ale           Pale Ale
# United States, Washington        Pale Ale     Pale Ale           Pale Ale
# United States, West Virginia     Pale Ale        Lager        Belgian Ale
# United States, Wisconsin            Stout        Stout              Stout
# United States, Wyoming           Pale Ale     Pale Ale           Pale Ale
#
# [71 rows x 12 columns]

# %% [markdown]
# ### *Rating-based beer style preferences - Clustered*

# %%
style_ratings_by_year_clustered = style_ratings_by_year.replace(inverted_beer_styles_dict)
style_ratings_by_year_clustered
# Out:
#                                            2006               2007  \
# location
# Australia                           Belgian Ale        Belgian Ale
# Belgium                             Belgian Ale        Belgian Ale
# Brazil                               Wheat Beer        Belgian Ale
# Canada                              Belgian Ale        Belgian Ale
# Croatia                             Belgian Ale             Porter
# ...                                         ...                ...
# United States, Virginia             Belgian Ale        Belgian Ale
# United States, Washington           Belgian Ale        Belgian Ale
# United States, West Virginia               Bock              Stout
# United States, Wisconsin      Lambic & Sour Ale  Lambic & Sour Ale
# United States, Wyoming                 Pale Ale              Stout
#
#                                            2008               2009  \
# location
# Australia                           Belgian Ale        Belgian Ale
# Belgium                             Belgian Ale        Belgian Ale
# Brazil                              Belgian Ale        Belgian Ale
# Canada                              Belgian Ale        Belgian Ale
# Croatia                             Belgian Ale              Stout
# ...                                         ...                ...
# United States, Virginia       Lambic & Sour Ale  Lambic & Sour Ale
# United States, Washington     Lambic & Sour Ale  Lambic & Sour Ale
# United States, West Virginia        Belgian Ale        Belgian Ale
# United States, Wisconsin      Lambic & Sour Ale              Stout
# United States, Wyoming                    Stout  Lambic & Sour Ale
#
#                                            2010               2011  \
# location
# Australia                           Belgian Ale        Belgian Ale
# Belgium                             Belgian Ale  Lambic & Sour Ale
# Brazil                                    Stout  Lambic & Sour Ale
# Canada                              Belgian Ale        Belgian Ale
# Croatia                                   Stout              Stout
# ...                                         ...                ...
# United States, Virginia       Lambic & Sour Ale  Lambic & Sour Ale
# United States, Washington     Lambic & Sour Ale  Lambic & Sour Ale
# United States, West Virginia        Belgian Ale        Belgian Ale
# United States, Wisconsin      Lambic & Sour Ale  Lambic & Sour Ale
# United States, Wyoming                    Stout           Pale Ale
#
#                                            2012               2013  \
# location
# Australia                           Belgian Ale               Bock
# Belgium                             Belgian Ale              Stout
# Brazil                              Belgian Ale        Belgian Ale
# Canada                        Lambic & Sour Ale        Belgian Ale
# Croatia                                   Stout              Stout
# ...                                         ...                ...
# United States, Virginia       Lambic & Sour Ale  Lambic & Sour Ale
# United States, Washington     Lambic & Sour Ale  Lambic & Sour Ale
# United States, West Virginia        Belgian Ale        Belgian Ale
# United States, Wisconsin      Lambic & Sour Ale  Lambic & Sour Ale
# United States, Wyoming                    Stout              Stout
#
#                                            2014               2015  \
# location
# Australia                           Belgian Ale  Lambic & Sour Ale
# Belgium                               Brown Ale              Stout
# Brazil                              Belgian Ale        Belgian Ale
# Canada                              Belgian Ale  Lambic & Sour Ale
# Croatia                                   Stout              Stout
# ...                                         ...                ...
# United States, Virginia       Lambic & Sour Ale  Lambic & Sour Ale
# United States, Washington     Lambic & Sour Ale  Lambic & Sour Ale
# United States, West Virginia              Stout  Lambic & Sour Ale
# United States, Wisconsin                  Stout  Lambic & Sour Ale
# United States, Wyoming        Lambic & Sour Ale              Stout
#
#                                            2016               2017
# location
# Australia                                 Stout        Belgian Ale
# Belgium                                   Stout              Stout
# Brazil                              Belgian Ale        Belgian Ale
# Canada                        Lambic & Sour Ale  Lambic & Sour Ale
# Croatia                             Belgian Ale  Lambic & Sour Ale
# ...                                         ...                ...
# United States, Virginia       Lambic & Sour Ale  Lambic & Sour Ale
# United States, Washington     Lambic & Sour Ale  Lambic & Sour Ale
# United States, West Virginia              Stout        Belgian Ale
# United States, Wisconsin      Lambic & Sour Ale  Lambic & Sour Ale
# United States, Wyoming                    Stout              Stout
#
# [71 rows x 12 columns]

# %% [markdown]
# ### *Popularity-based brewery location preferences - Clustered*

# %%
bc_popularities_by_year_clustered = bc_popularities_by_year.replace(inverted_location_dict)
bc_popularities_by_year_clustered
# Out:
#                                                    2006  \
# location
# Australia                                       Oceania
# Belgium                          Central/Western Europe
# Brazil                        Central and South America
# Canada                                    North America
# Croatia                          Central/Western Europe
# ...                                                 ...
# United States, Virginia                   North America
# United States, Washington                 North America
# United States, West Virginia              North America
# United States, Wisconsin                  North America
# United States, Wyoming                    North America
#
#                                                 2007  \
# location
# Australia                                    Oceania
# Belgium                       Central/Western Europe
# Brazil                        Central/Western Europe
# Canada                                 North America
# Croatia                       Central/Western Europe
# ...                                              ...
# United States, Virginia                North America
# United States, Washington              North America
# United States, West Virginia           North America
# United States, Wisconsin               North America
# United States, Wyoming                 North America
#
#                                                    2008  \
# location
# Australia                                       Oceania
# Belgium                          Central/Western Europe
# Brazil                        Central and South America
# Canada                                    North America
# Croatia                          Central/Western Europe
# ...                                                 ...
# United States, Virginia                   North America
# United States, Washington                 North America
# United States, West Virginia              North America
# United States, Wisconsin                  North America
# United States, Wyoming                    North America
#
#                                                    2009  \
# location
# Australia                                       Oceania
# Belgium                          Central/Western Europe
# Brazil                        Central and South America
# Canada                                    North America
# Croatia                          Central/Western Europe
# ...                                                 ...
# United States, Virginia                   North America
# United States, Washington                 North America
# United States, West Virginia              North America
# United States, Wisconsin                  North America
# United States, Wyoming                    North America
#
#                                                    2010  \
# location
# Australia                                       Oceania
# Belgium                          Central/Western Europe
# Brazil                        Central and South America
# Canada                                    North America
# Croatia                          Central/Western Europe
# ...                                                 ...
# United States, Virginia                   North America
# United States, Washington                 North America
# United States, West Virginia              North America
# United States, Wisconsin                  North America
# United States, Wyoming                    North America
#
#                                                    2011  \
# location
# Australia                                       Oceania
# Belgium                          Central/Western Europe
# Brazil                        Central and South America
# Canada                                    North America
# Croatia                          Central/Western Europe
# ...                                                 ...
# United States, Virginia                   North America
# United States, Washington                 North America
# United States, West Virginia              North America
# United States, Wisconsin                  North America
# United States, Wyoming                    North America
#
#                                                    2012  \
# location
# Australia                                       Oceania
# Belgium                          Central/Western Europe
# Brazil                        Central and South America
# Canada                                    North America
# Croatia                          Central/Western Europe
# ...                                                 ...
# United States, Virginia                   North America
# United States, Washington                 North America
# United States, West Virginia              North America
# United States, Wisconsin                  North America
# United States, Wyoming                    North America
#
#                                                    2013  \
# location
# Australia                                       Oceania
# Belgium                          Central/Western Europe
# Brazil                        Central and South America
# Canada                                    North America
# Croatia                          Central/Western Europe
# ...                                                 ...
# United States, Virginia                   North America
# United States, Washington                 North America
# United States, West Virginia              North America
# United States, Wisconsin                  North America
# United States, Wyoming                    North America
#
#                                                    2014  \
# location
# Australia                                       Oceania
# Belgium                          Central/Western Europe
# Brazil                        Central and South America
# Canada                                    North America
# Croatia                          Central/Western Europe
# ...                                                 ...
# United States, Virginia                   North America
# United States, Washington                 North America
# United States, West Virginia              North America
# United States, Wisconsin                  North America
# United States, Wyoming                    North America
#
#                                                    2015  \
# location
# Australia                                       Oceania
# Belgium                          Central/Western Europe
# Brazil                        Central and South America
# Canada                                    North America
# Croatia                          Central/Western Europe
# ...                                                 ...
# United States, Virginia                   North America
# United States, Washington                 North America
# United States, West Virginia              North America
# United States, Wisconsin                  North America
# United States, Wyoming                    North America
#
#                                                    2016  \
# location
# Australia                                       Oceania
# Belgium                          Central/Western Europe
# Brazil                        Central and South America
# Canada                                    North America
# Croatia                                 Southern Europe
# ...                                                 ...
# United States, Virginia                   North America
# United States, Washington                 North America
# United States, West Virginia              North America
# United States, Wisconsin                  North America
# United States, Wyoming                    North America
#
#                                                    2017
# location
# Australia                                       Oceania
# Belgium                          Central/Western Europe
# Brazil                        Central and South America
# Canada                                    North America
# Croatia                                 Southern Europe
# ...                                                 ...
# United States, Virginia                   North America
# United States, Washington                 North America
# United States, West Virginia              North America
# United States, Wisconsin                  North America
# United States, Wyoming                    North America
#
# [71 rows x 12 columns]

# %% [markdown]
# ### *Rating-based brewery location preferences - Clustered*

# %%
bc_ratings_by_year_clustered = bc_ratings_by_year.replace(inverted_location_dict)
bc_ratings_by_year_clustered
# Out:
#                                                 2006                    2007  \
# location
# Australia                              North America           North America
# Belgium                                North America           North America
# Brazil                        Central/Western Europe           North America
# Canada                                 North America         Northern Europe
# Croatia                       Central/Western Europe  Central/Western Europe
# ...                                              ...                     ...
# United States, Virginia                North America           North America
# United States, Washington              North America         Northern Europe
# United States, West Virginia           North America  Central/Western Europe
# United States, Wisconsin               North America         Northern Europe
# United States, Wyoming        Central/Western Europe           North America
#
#                                                 2008                    2009  \
# location
# Australia                              North America         Northern Europe
# Belgium                                North America           North America
# Brazil                                 North America  Central/Western Europe
# Canada                               Northern Europe         Northern Europe
# Croatia                       Central/Western Europe          United Kingdom
# ...                                              ...                     ...
# United States, Virginia              Northern Europe         Northern Europe
# United States, Washington            Northern Europe         Northern Europe
# United States, West Virginia           North America  Central/Western Europe
# United States, Wisconsin             Northern Europe           North America
# United States, Wyoming        Central/Western Europe  Central/Western Europe
#
#                                                 2010                    2011  \
# location
# Australia                            Northern Europe           North America
# Belgium                                North America         Northern Europe
# Brazil                        Central/Western Europe           North America
# Canada                               Northern Europe         Northern Europe
# Croatia                               United Kingdom         Northern Europe
# ...                                              ...                     ...
# United States, Virginia                North America           North America
# United States, Washington              North America  Central/Western Europe
# United States, West Virginia  Central/Western Europe  Central/Western Europe
# United States, Wisconsin             Northern Europe         Northern Europe
# United States, Wyoming                 North America           North America
#
#                                                 2012                    2013  \
# location
# Australia                              North America         Northern Europe
# Belgium                                North America           North America
# Brazil                        Central/Western Europe           North America
# Canada                                 North America           North America
# Croatia                       Central/Western Europe          United Kingdom
# ...                                              ...                     ...
# United States, Virginia                North America           North America
# United States, Washington     Central/Western Europe           North America
# United States, West Virginia           North America  Central/Western Europe
# United States, Wisconsin             Northern Europe           North America
# United States, Wyoming        Central/Western Europe           North America
#
#                                                 2014             2015  \
# location
# Australia                              North America  Northern Europe
# Belgium                                North America    North America
# Brazil                                 North America    North America
# Canada                                 North America    North America
# Croatia                              Northern Europe  Northern Europe
# ...                                              ...              ...
# United States, Virginia                North America  Northern Europe
# United States, Washington              North America    North America
# United States, West Virginia  Central/Western Europe    North America
# United States, Wisconsin               North America    North America
# United States, Wyoming                 North America    North America
#
#                                                 2016           2017
# location
# Australia                              North America  North America
# Belgium                                North America  North America
# Brazil                                 North America  North America
# Canada                                 North America  North America
# Croatia                              Northern Europe  North America
# ...                                              ...            ...
# United States, Virginia       Central/Western Europe  North America
# United States, Washington              North America  North America
# United States, West Virginia  Central/Western Europe  North America
# United States, Wisconsin               North America  North America
# United States, Wyoming                United Kingdom  North America
#
# [71 rows x 12 columns]

# %% [markdown]
# ## *The beer preference similarities between locations and their temporal evolutions*

# %% [markdown]
# Having the beer preferences for each location, we now want to see how similar the locations are in terms of their beer preferences. For this, we need to define a similarity metric. Remember that we have preferences in terms of beer styles and brewery locations and one metric for each of them is needed.
#
# For beer styles, we use the Jaccard similarity metric. Note that the top 3 beer style preference was provided for each location at each year. The beer style preference similarity of two locations is calculated between their corresponding beer style preference sets of size 3.
#
# For the brewery locations, we use inverse of the geographical distance between the preferred brewery locations of the two locations to define how 'similar' their preferred brewery locations are.

# %%
#To compute the distance between the breweries, we need to get the latitudes and longitudes of the breweries and store them in a dictionary:
brewery_locations = breweries['location'].unique()
brewery_latitudes_longitudes = []
for location in brewery_locations:
    try:
        res = geocode_location(location)
    except:
        continue
    if res:
        lat,long = res
        brewery_latitudes_longitudes.append([lat, long])

ll_dict = dict(zip(brewery_locations, brewery_latitudes_longitudes))

# %% [markdown]
# Below, we calculate the beer style and brewery location similarities between each pair of locations. For this, we use the function 'compute_similarity_countries()' defined in helpers.py file. The function takes a boolean argument called 'jaccard_flag' and if it is True, the preference similarities are calculated based on beer styles. Otherwise, the preference similarities are calculated based on brewery locations. The global similarity is defined as the mean of similarities calculated for each pair.

# %%
#Get the preference similarities between each pair of locations for each of the 4 categories
style_similarity_ratings = compute_similarity_countries(style_ratings_by_year_top3, ll_dict, jaccard_flag = True )
style_similarity_popularity = compute_similarity_countries(style_popularities_by_year_top3, ll_dict,  jaccard_flag = True)
brewery_similarity_popularity = compute_similarity_countries(bc_popularities_by_year, ll_dict, jaccard_flag = False)
brewery_similarity_ratings =compute_similarity_countries(bc_ratings_by_year, ll_dict, jaccard_flag = False)

column_names = ['location 1', 'location 2'] + [str(x) for x in range(2006, 2018)] # Giving consistent labels for each dataframe
similarity_columns = column_names[2:]

#Giving each dataframe the above-defined labels
style_similarity_ratings.columns = column_names
style_similarity_popularity.columns = column_names
brewery_similarity_popularity.columns = column_names
brewery_similarity_ratings.columns = column_names

#We plot the mean (global) similarity for each year, for each metric
style_ratings_mean = style_similarity_ratings[similarity_columns].mean().tolist()
style_popularity_mean = style_similarity_popularity[similarity_columns].mean().tolist()
brewery_popularity_mean = brewery_similarity_popularity[similarity_columns].mean().tolist()
brewery_ratings_mean = brewery_similarity_ratings[similarity_columns].mean().tolist()

fig, axs = plt.subplots(1, 2, figsize=(14, 4))
plt.rc('xtick', labelsize=12)
plt.rc('ytick', labelsize=12)

axs[0].scatter(similarity_columns, style_ratings_mean, label='Style ratings mean')
axs[0].plot(similarity_columns, style_ratings_mean, linestyle='-', marker='', color='blue')
axs[0].scatter(similarity_columns, style_popularity_mean, label='Style popularity mean')
axs[0].plot(similarity_columns, style_popularity_mean, linestyle='-', marker='', color='orange')

# Customize the plots
axs[0].set_title('Beer preference similarity with respect to top styles', fontsize=14)
axs[0].set_xlabel('Year', fontsize=14)
axs[0].set_ylabel('Global Similarity', fontsize=14)
axs[0].legend()

axs[1].scatter(similarity_columns, brewery_ratings_mean, label='Brewery ratings mean')
axs[1].plot(similarity_columns, brewery_ratings_mean, linestyle='-', marker='', color='blue')
axs[1].scatter(similarity_columns, brewery_popularity_mean, label='Brewery popularity mean')
axs[1].plot(similarity_columns, brewery_popularity_mean, linestyle='-', marker='', color='orange')
axs[1].set_title('Beer preference similarity with respect to favorite breweries', fontsize=14)
axs[1].set_xlabel('Year', fontsize=14)
axs[1].set_ylabel('Global Similarity', fontsize=14)
axs[1].legend()

plt.show()

# %% [markdown]
# ## *Investigating the role of geographical distance between locations in the similarities of their beer preferences*

# %%
#Finding the latitude and longitude of each location
location_list = users['location'].unique().tolist()
latitudes_longitudes = get_lat_long(location_list)

#We investigated the returned latitudes and longtitudes and found two of them (Germany and Sweden) are not correct. Therefore, we manually corrected them.
latitudes_longitudes['Germany'] = (52.517037, 13.388860)
latitudes_longitudes['Sweden'] = (59.329323, 18.068581)
location_distances_dict, location_distances_df = get_location_df(latitudes_longitudes)
location_distances_df
# Out:
#                                    Poland        Spain      Germany  \
# Poland                           0.000000  2332.787621   392.689746
# Spain                         2332.787621     0.000000  2025.543046
# Germany                        392.689746  2025.543046     0.000000
# Belgium                       1019.589163  1461.145792   639.180588
# United States, Connecticut    6613.969522  5608.065761  6252.550733
# ...                                   ...          ...          ...
# United States, West Virginia  7344.825413  6382.889559  6990.636061
# United States, North Dakota   7551.433482  7290.895017  7269.465519
# United States, Vermont        6373.101297  5477.343851  6018.529943
# United States, Rhode Island   6535.084658  5514.096505  6172.161518
# United States, Montana        7944.769552  7868.668596  7689.405018
#
#                                   Belgium  United States, Connecticut  \
# Poland                        1019.589163                 6613.969522
# Spain                         1461.145792                 5608.065761
# Germany                        639.180588                 6252.550733
# Belgium                          0.000000                 5785.529323
# United States, Connecticut    5785.529323                    0.000000
# ...                                   ...                         ...
# United States, West Virginia  6540.877458                  775.786341
# United States, North Dakota   6990.273001                 2289.799738
# United States, Vermont        5572.578048                  328.177686
# United States, Rhode Island   5701.024946                   95.825862
# United States, Montana        7462.528206                 2973.036206
#
#                               United States, Virginia  \
# Poland                                    7319.718518
# Spain                                     6265.917614
# Germany                                   6958.384695
# Belgium                                   6488.498227
# United States, Connecticut                 705.865313
# ...                                               ...
# United States, West Virginia               255.531380
# United States, North Dakota               2146.289427
# United States, Vermont                     971.198066
# United States, Rhode Island                787.647086
# United States, Montana                    2787.079278
#
#                               United States, Washington     Scotland  \
# Poland                                      7088.226412  1580.637627
# Spain                                       6064.937138  1942.114313
# Germany                                     6728.012976  1221.267157
# Belgium                                     6262.361076   895.244555
# United States, Connecticut                   476.841688  5034.295658
# ...                                                 ...          ...
# United States, West Virginia                 334.236304  5769.689598
# United States, North Dakota                 2128.889995  6110.508322
# United States, Vermont                       737.094594  4797.584798
# United States, Rhode Island                  563.010666  4954.905661
# United States, Montana                      2790.555626  6571.405637
#
#                                   Denmark       Sweden  ...  \
# Poland                         693.338093   794.777292  ...
# Spain                         2136.298071  2748.943427  ...
# Germany                        403.826466   812.456840  ...
# Belgium                        675.566205  1288.194624  ...
# United States, Connecticut    5926.794605  6189.586790  ...
# ...                                   ...          ...  ...
# United States, West Virginia  6653.999055  6884.457805  ...
# United States, North Dakota   6878.532586  6906.796827  ...
# United States, Vermont        5682.644417  5922.809538  ...
# United States, Rhode Island   5848.909635  6118.153809  ...
# United States, Montana        7290.700772  7257.610457  ...
#
#                               United States, Hawaii  United States, Arkansas  \
# Poland                                 12031.742215              8276.342961
# Spain                                  12804.256247              7460.486978
# Germany                                11942.867607              7939.816272
# Belgium                                11984.262032              7531.743849
# United States, Connecticut              7995.455651              1858.676981
# ...                                             ...                      ...
# United States, West Virginia            7364.234808              1096.152010
# United States, North Dakota             5808.601947              1533.875663
# United States, Vermont                  7956.999573              1991.345585
# United States, Rhode Island             8085.186792              1953.994740
# United States, Montana                  5144.317971              1966.667619
#
#                               United States, Kentucky  United States, Wyoming  \
# Poland                                    7667.028506             8265.040069
# Spain                                     6764.492292             8024.661846
# Germany                                   7319.437793             7991.263966
# Belgium                                   6885.998357             7724.292042
# United States, Connecticut                1157.333287             2851.698831
# ...                                               ...                     ...
# United States, West Virginia               391.809785             2303.612225
# United States, North Dakota               1679.690024              739.341616
# United States, Vermont                    1316.416864             2800.861316
# United States, Rhode Island               1252.114682             2938.565889
# United States, Montana                    2275.122059              494.737928
#
#                               United States, Alaska  \
# Poland                                  7031.033661
# Spain                                   8095.769209
# Germany                                 6951.621279
# Belgium                                 7050.608194
# United States, Connecticut              5323.578080
# ...                                             ...
# United States, West Virginia            5227.479056
# United States, North Dakota             3463.039914
# United States, Vermont                  5067.584122
# United States, Rhode Island             5363.849009
# United States, Montana                  3059.455299
#
#                               United States, West Virginia  \
# Poland                                         7344.825413
# Spain                                          6382.889559
# Germany                                        6990.636061
# Belgium                                        6540.877458
# United States, Connecticut                      775.786341
# ...                                                    ...
# United States, West Virginia                      0.000000
# United States, North Dakota                    1891.197325
# United States, Vermont                          972.109217
# United States, Rhode Island                     868.995409
# United States, Montana                         2531.858029
#
#                               United States, North Dakota  \
# Poland                                        7551.433482
# Spain                                         7290.895017
# Germany                                       7269.465519
# Belgium                                       6990.273001
# United States, Connecticut                    2289.799738
# ...                                                   ...
# United States, West Virginia                  1891.197325
# United States, North Dakota                      0.000000
# United States, Vermont                        2181.397620
# United States, Rhode Island                   2367.553136
# United States, Montana                         685.653656
#
#                               United States, Vermont  \
# Poland                                   6373.101297
# Spain                                    5477.343851
# Germany                                  6018.529943
# Belgium                                  5572.578048
# United States, Connecticut                328.177686
# ...                                              ...
# United States, West Virginia              972.109217
# United States, North Dakota              2181.397620
# United States, Vermont                      0.000000
# United States, Rhode Island               319.874873
# United States, Montana                   2866.481173
#
#                               United States, Rhode Island  \
# Poland                                        6535.084658
# Spain                                         5514.096505
# Germany                                       6172.161518
# Belgium                                       5701.024946
# United States, Connecticut                      95.825862
# ...                                                   ...
# United States, West Virginia                   868.995409
# United States, North Dakota                   2367.553136
# United States, Vermont                         319.874873
# United States, Rhode Island                      0.000000
# United States, Montana                        3051.867234
#
#                               United States, Montana
# Poland                                   7944.769552
# Spain                                    7868.668596
# Germany                                  7689.405018
# Belgium                                  7462.528206
# United States, Connecticut               2973.036206
# ...                                              ...
# United States, West Virginia             2531.858029
# United States, North Dakota               685.653656
# United States, Vermont                   2866.481173
# United States, Rhode Island              3051.867234
# United States, Montana                      0.000000
#
# [71 rows x 71 columns]

# %%
#For each location, retrieve the closest 15 locations and the farthest 15 locations from it and store them in a dictionary
fifteen_closest_locations, fifteen_farthest_locations = k_closest_and_farthest_locations(15, all_differences_dict = location_distances_dict)

# %%
#Get the similarity for each group, for each of our metrics
closest_style_ratings, farthest_style_ratings = get_group_similarities(ratings, style_ratings_by_year_top3, k_closest_locs= fifteen_closest_locations, k_farthest_locs=fifteen_farthest_locations, ll_dict=ll_dict, jaccard_flag= True)
closest_style_popularity, farthest_style_popularity = get_group_similarities(ratings, style_popularities_by_year_top3, k_closest_locs= fifteen_closest_locations, k_farthest_locs=fifteen_farthest_locations, ll_dict=ll_dict, jaccard_flag= True)
closest_bc_ratings, farthest_bc_ratings = get_group_similarities(ratings, bc_ratings_by_year, k_closest_locs= fifteen_closest_locations, k_farthest_locs=fifteen_farthest_locations, ll_dict=ll_dict, jaccard_flag= False)
closest_bc_pop, farthest_bc_pop = get_group_similarities(ratings, bc_popularities_by_year, k_closest_locs=fifteen_closest_locations, k_farthest_locs=fifteen_farthest_locations, ll_dict=ll_dict, jaccard_flag=False)

# %% [markdown]
# ### *Style preference similarities based on distance*

# %%
rename_columns = [str(x) for x in range(2006, 2018)]
closest_style_ratings.columns = farthest_style_ratings.columns = closest_style_popularity.columns = farthest_style_popularity.columns = closest_bc_ratings.columns = farthest_bc_ratings.columns = closest_bc_pop.columns = farthest_bc_pop.columns = rename_columns

plot_graphs(rename_columns, closest_style_ratings, farthest_style_ratings, style_similarity_ratings, closest_style_popularity, farthest_style_popularity, style_similarity_popularity, brewery_or_style = 'Preferred Beer Style', wealth_flag='distance')

# %% [markdown]
# The results conform with the intuition as the global similarity curve is almost always between the closest and farthest similarity curves. Furthermore, we see that the rating based similarities have an increasing trend versus time whereas the popularity (consumption rate) similarities display both increasing and decreasing behavior and are roughly at the same level at the beginning and end of our time range.

# %% [markdown]
# Using the t_test_dataframe() function, we perform a t-test to see if the beer style preference difference between the mean similarity of the closest locations and the mean similarity of the farthest locations is statistically significant.

# %%
t_test_dataframe(rename_columns, closest_style_ratings, farthest_style_ratings, style_similarity_ratings, closest_style_popularity, farthest_style_popularity, style_similarity_popularity)
# Out:
#     year  closest vs farthest p-value based on rating  \
# 0   2006                                 5.518756e-20
# 1   2007                                 3.983086e-04
# 2   2008                                 2.877097e-05
# 3   2009                                 3.956077e-04
# 4   2010                                 8.310089e-02
# 5   2011                                 3.072113e-12
# 6   2012                                 7.748140e-13
# 7   2013                                 6.576252e-18
# 8   2014                                 1.370447e-29
# 9   2015                                 2.172962e-22
# 10  2016                                 2.908735e-09
# 11  2017                                 6.923422e-06
#
#     closest vs farthest p-value based on popularity
# 0                                     1.849850e-115
# 1                                     4.719124e-116
# 2                                     1.026889e-169
# 3                                     6.343645e-174
# 4                                     1.248428e-209
# 5                                     9.923109e-223
# 6                                     1.241651e-189
# 7                                     4.058422e-177
# 8                                     1.899871e-152
# 9                                     1.710910e-145
# 10                                     2.561202e-78
# 11                                     9.344304e-57

# %% [markdown]
# **As we can see, the p value is lower than 0.05 in all years based on differences in both rating and consumption categories, expect for p-value from the year 2010 based on rating. So we can say in general that the beer style preference similarity significantly differs depending on whether it is calculated among geographically close or far locations. Furthermore, p values based on popularity is much smaller than the p-values based on rating. Therefore, geographic distance seems to play a bigger role on popularity (consumption rate) differences than rating differences.**

# %% [markdown]
# ### *Brewery location preference similarities based on distance*

# %%
plot_graphs(rename_columns, closest_bc_ratings, farthest_bc_ratings, brewery_similarity_ratings, closest_bc_pop, farthest_bc_pop, brewery_similarity_popularity, brewery_or_style = 'Preferred Brewery Location', wealth_flag='distance')

# %% [markdown]
# The results again conform with the intuition as the global similarity curve is almost always between the closest and farthest similarity curves. This time, we see that the rating based similarities have a decreasing trend (especially in the later years) versus time whereas the popularity (consumption rate) similarities display both increasing and decreasing behavior and are roughly at the same level at the beginning and end of our time range.

# %% [markdown]
# Using the t_test_dataframe() function, we perform a t-test to see if the brewery location preference difference between the mean similarity of the closest locations and the mean similarity of the farthest locations is statistically significant.

# %%
t_test_dataframe(rename_columns, closest_bc_ratings, farthest_bc_ratings, brewery_similarity_ratings, closest_bc_pop, farthest_bc_pop, brewery_similarity_popularity)
# Out:
#     year  closest vs farthest p-value based on rating  \
# 0   2006                                 1.991908e-02
# 1   2007                                 3.152877e-12
# 2   2008                                 9.269373e-08
# 3   2009                                 4.608729e-05
# 4   2010                                 2.045135e-02
# 5   2011                                 2.143100e-01
# 6   2012                                 2.184488e-03
# 7   2013                                 3.440864e-02
# 8   2014                                 2.660561e-04
# 9   2015                                 5.244895e-09
# 10  2016                                 6.950922e-05
# 11  2017                                 2.639141e-02
#
#     closest vs farthest p-value based on popularity
# 0                                      4.276648e-86
# 1                                      2.036664e-87
# 2                                     4.589186e-115
# 3                                     5.953743e-147
# 4                                     2.499257e-122
# 5                                     1.823481e-159
# 6                                     6.423444e-118
# 7                                     5.201383e-140
# 8                                     1.252228e-106
# 9                                      7.183880e-88
# 10                                     4.693286e-93
# 11                                     1.323061e-88

# %% [markdown]
# **As we can see, the p value is lower than 0.05 in all years based on differences in both rating and consumption categories, expect for p-value from the year 2006 based on rating. So we can say in general that the brewery location preference similarity significantly differs depending on whether it is calculated among geographically close or far locations. Furthermore, p-values based on popularity is much smaller than the p-values based on rating. Therefore, geographic distance seems to play a bigger role on popularity (consumption rate) differences than rating differences.**

# %% [markdown]
# ## *Investigating the role of wealth (GDP per capita) of locations in the similarities of their beer preferences*

# %% [markdown]
# We know look at GDP per capita as a second potential factor that might affect the similarity of beer preferences between locations. We use the GDP per capita data from the World Bank. We use the data from 2008 as it was the only year for which we could find reliable data and it falls in our time range. First, we calculate the absolute difference of GDP per capita between each pair of locations and store them in a dictionary.

# %%
closest_and_farthest_distance = pd.read_csv('dataset/AdditionalData/Wealth_and_Lang.csv')

wealth_dict = {}
for index, row in closest_and_farthest_distance.iterrows():
    wealth_dict[row['Location']] = row['Money in 2008']

wealth_differences_dict = {}
for first_location in wealth_dict:
    wealth_differences_dict[first_location] = {}
    for second_location in wealth_dict:
        wealth_differences_dict[first_location][second_location] = abs(wealth_dict[first_location] - wealth_dict[second_location])

pd.DataFrame(wealth_differences_dict)
# Out:
#                               United States, California  \
# United States, California                         0.000
# United States, Pennsylvania                    7211.000
# United States, New York                        2759.000
# United States, Illinois                        1516.140
# United States, Massachusetts                   6665.000
# ...                                                 ...
# Croatia                                       40060.300
# United States, Wyoming                        20390.537
# Northern Ireland                              24689.130
# Iceland                                        1025.400
# Luxembourg                                    64504.100
#
#                               United States, Pennsylvania  \
# United States, California                        7211.000
# United States, Pennsylvania                         0.000
# United States, New York                          9970.000
# United States, Illinois                          5694.860
# United States, Massachusetts                    13876.000
# ...                                                   ...
# Croatia                                         32849.300
# United States, Wyoming                          27601.537
# Northern Ireland                                17478.130
# Iceland                                          8236.400
# Luxembourg                                      71715.100
#
#                               United States, New York  \
# United States, California                    2759.000
# United States, Pennsylvania                  9970.000
# United States, New York                         0.000
# United States, Illinois                      4275.140
# United States, Massachusetts                 3906.000
# ...                                               ...
# Croatia                                     42819.300
# United States, Wyoming                      17631.537
# Northern Ireland                            27448.130
# Iceland                                      1733.600
# Luxembourg                                  61745.100
#
#                               United States, Illinois  \
# United States, California                    1516.140
# United States, Pennsylvania                  5694.860
# United States, New York                      4275.140
# United States, Illinois                         0.000
# United States, Massachusetts                 8181.140
# ...                                               ...
# Croatia                                     38544.160
# United States, Wyoming                      21906.677
# Northern Ireland                            23172.990
# Iceland                                      2541.540
# Luxembourg                                  66020.240
#
#                               United States, Massachusetts  \
# United States, California                         6665.000
# United States, Pennsylvania                      13876.000
# United States, New York                           3906.000
# United States, Illinois                           8181.140
# United States, Massachusetts                         0.000
# ...                                                    ...
# Croatia                                          46725.300
# United States, Wyoming                           13725.537
# Northern Ireland                                 31354.130
# Iceland                                           5639.600
# Luxembourg                                       57839.100
#
#                               United States, Texas     Canada  \
# United States, California                 4103.000   9208.000
# United States, Pennsylvania               3108.000   1997.000
# United States, New York                   6862.000  11967.000
# United States, Illinois                   2586.860   7691.860
# United States, Massachusetts             10768.000  15873.000
# ...                                            ...        ...
# Croatia                                  35957.300  30852.300
# United States, Wyoming                   24493.537  29598.537
# Northern Ireland                         20586.130  15481.130
# Iceland                                   5128.400  10233.400
# Luxembourg                               68607.100  73712.100
#
#                               United States, Ohio  United States, Florida  \
# United States, California                9761.968               12564.636
# United States, Pennsylvania              2550.968                5353.636
# United States, New York                 12520.968               15323.636
# United States, Illinois                  8245.828               11048.496
# United States, Massachusetts            16426.968               19229.636
# ...                                           ...                     ...
# Croatia                                 30298.332               27495.664
# United States, Wyoming                  30152.505               32955.173
# Northern Ireland                        14927.162               12124.494
# Iceland                                 10787.368               13590.036
# Luxembourg                              74266.068               77068.736
#
#                               United States, Michigan  ...  \
# United States, California                   14636.102  ...
# United States, Pennsylvania                  7425.102  ...
# United States, New York                     17395.102  ...
# United States, Illinois                     13119.962  ...
# United States, Massachusetts                21301.102  ...
# ...                                               ...  ...
# Croatia                                     25424.198  ...
# United States, Wyoming                      35026.639  ...
# Northern Ireland                            10053.028  ...
# Iceland                                     15661.502  ...
# Luxembourg                                  79140.202  ...
#
#                               United States, Idaho  United States, Montana  \
# United States, California                17031.232               14799.325
# United States, Pennsylvania               9820.232                7588.325
# United States, New York                  19790.232               17558.325
# United States, Illinois                  15515.092               13283.185
# United States, Massachusetts             23696.232               21464.325
# ...                                            ...                     ...
# Croatia                                  23029.068               25260.975
# United States, Wyoming                   37421.769               35189.862
# Northern Ireland                          7657.898                9889.805
# Iceland                                  18056.632               15824.725
# Luxembourg                               81535.332               79303.425
#
#                               United States, Alaska  United States, Hawaii  \
# United States, California                 18210.120               2280.160
# United States, Pennsylvania               25421.120               4930.840
# United States, New York                   15451.120               5039.160
# United States, Illinois                   19726.260                764.020
# United States, Massachusetts              11545.120               8945.160
# ...                                             ...                    ...
# Croatia                                   58270.420              37780.140
# United States, Wyoming                     2180.417              22670.697
# Northern Ireland                          42899.250              22408.970
# Iceland                                   17184.720               3305.560
# Luxembourg                                46293.980              66784.260
#
#                               United States, North Dakota     Croatia  \
# United States, California                       16438.100   40060.300
# United States, Pennsylvania                     23649.100   32849.300
# United States, New York                         13679.100   42819.300
# United States, Illinois                         17954.240   38544.160
# United States, Massachusetts                     9773.100   46725.300
# ...                                                   ...         ...
# Croatia                                         56498.400       0.000
# United States, Wyoming                           3952.437   60450.837
# Northern Ireland                                41127.230   15371.170
# Iceland                                         15412.700   41085.700
# Luxembourg                                      48066.000  104564.400
#
#                               United States, Wyoming  Northern Ireland  \
# United States, California                  20390.537         24689.130
# United States, Pennsylvania                27601.537         17478.130
# United States, New York                    17631.537         27448.130
# United States, Illinois                    21906.677         23172.990
# United States, Massachusetts               13725.537         31354.130
# ...                                              ...               ...
# Croatia                                    60450.837         15371.170
# United States, Wyoming                         0.000         45079.667
# Northern Ireland                           45079.667             0.000
# Iceland                                    19365.137         25714.530
# Luxembourg                                 44113.563         89193.230
#
#                                 Iceland  Luxembourg
# United States, California      1025.400   64504.100
# United States, Pennsylvania    8236.400   71715.100
# United States, New York        1733.600   61745.100
# United States, Illinois        2541.540   66020.240
# United States, Massachusetts   5639.600   57839.100
# ...                                 ...         ...
# Croatia                       41085.700  104564.400
# United States, Wyoming        19365.137   44113.563
# Northern Ireland              25714.530   89193.230
# Iceland                           0.000   63478.700
# Luxembourg                    63478.700       0.000
#
# [71 rows x 71 columns]

# %%
#For each location, retrieve the closest 15 locations and the farthest 15 locations from it (in terms of GDP per capita) and store them in a dictionary.
fifteen_closest_locations, fifteen_furthest_locations = k_closest_and_farthest_locations(15, wealth_differences_dict)

# %%
#Get the similarity for each group, for each of our metrics
closest_style_ratings, farthest_style_ratings = get_group_similarities(ratings, style_ratings_by_year_top3, k_closest_locs= fifteen_closest_locations, k_farthest_locs=fifteen_farthest_locations, ll_dict=ll_dict, jaccard_flag= True)
closest_style_popularity, farthest_style_popularity = get_group_similarities(ratings, style_popularities_by_year_top3, k_closest_locs= fifteen_closest_locations, k_farthest_locs=fifteen_farthest_locations, ll_dict=ll_dict, jaccard_flag= True)
closest_bc_ratings, farthest_bc_ratings = get_group_similarities(ratings, bc_ratings_by_year, k_closest_locs= fifteen_closest_locations, k_farthest_locs=fifteen_farthest_locations, ll_dict=ll_dict, jaccard_flag= False)
closest_bc_pop, farthest_bc_pop = get_group_similarities(ratings, bc_popularities_by_year, k_closest_locs=fifteen_closest_locations, k_farthest_locs=fifteen_farthest_locations, ll_dict=ll_dict, jaccard_flag=False)

# %% [markdown]
# ### *Style preference similarities based on GDP per capita*

# %%
rename_columns = [str(x) for x in range(2006, 2018)]
closest_style_ratings.columns = farthest_style_ratings.columns = closest_style_popularity.columns = farthest_style_popularity.columns = closest_bc_ratings.columns = farthest_bc_ratings.columns = closest_bc_pop.columns = farthest_bc_pop.columns = rename_columns

plot_graphs(rename_columns, closest_style_ratings, farthest_style_ratings, style_similarity_ratings, closest_style_popularity, farthest_style_popularity, style_similarity_popularity, brewery_or_style = 'Preferred Beer Style', wealth_flag='GDP per capita')

# %% [markdown]
# The results again conform with the intuition as the global similarity curve is almost always between the closest and farthest similarity curves. Furthermore, we see that the rating based similarities have an increasing trend versus time whereas the popularity (consumption rate) similarities display both increasing and decreasing behavior and are roughly at the same level at the beginning and end of our time range.

# %% [markdown]
# Using the t_test_dataframe() function, we perform a t-test to see if the beer style preference difference between the mean similarity of the closest locations and the mean similarity of the farthest locations (in terms of GDP per capita) is statistically significant.

# %%
t_test_dataframe(rename_columns, closest_style_ratings, farthest_style_ratings, style_similarity_ratings, closest_style_popularity, farthest_style_popularity, style_similarity_popularity)
# Out:
#     year  closest vs farthest p-value based on rating  \
# 0   2006                                 9.662968e-18
# 1   2007                                 4.262418e-05
# 2   2008                                 2.553832e-01
# 3   2009                                 2.406347e-02
# 4   2010                                 9.638195e-01
# 5   2011                                 5.291014e-11
# 6   2012                                 1.261669e-06
# 7   2013                                 1.117951e-11
# 8   2014                                 3.235528e-11
# 9   2015                                 3.469751e-13
# 10  2016                                 7.937899e-09
# 11  2017                                 4.227165e-06
#
#     closest vs farthest p-value based on popularity
# 0                                      1.691313e-52
# 1                                      1.523394e-58
# 2                                      8.765347e-95
# 3                                      1.999146e-88
# 4                                      1.429861e-98
# 5                                     4.244575e-125
# 6                                     4.502770e-107
# 7                                     2.587148e-100
# 8                                      2.741773e-80
# 9                                      4.707994e-73
# 10                                     7.013582e-55
# 11                                     1.763522e-33

# %% [markdown]
# **As we can see, the p-value is lower than 0.05 in all years based on differences in both rating and consumption categories, expect for p-value from the years 2008 and 2010 based on rating. So we can say in general that the beer style preference similarity significantly differs depending on whether it is calculated among close or far locations in terms of GDP per capita. Furthermore, p-values based on popularity is much smaller than the p-values based on rating. Therefore, GDP per capita difference seems to play a bigger role on popularity (consumption rate) differences than rating differences.**

# %% [markdown]
# ### *Brewery location preference similarities based on GDP per capita*

# %%
plot_graphs(rename_columns, closest_bc_ratings, farthest_bc_ratings, brewery_similarity_ratings, closest_bc_pop, farthest_bc_pop, brewery_similarity_popularity, brewery_or_style = 'Preferred Brewery Location', wealth_flag='wealth')

# %% [markdown]
# The results again conform with the intuition as the global similarity curve is almost always between the closest and farthest similarity curves. Furthermore, we see that the rating based similarities have a decreasing trend versus time (especially for the later years), whereas the popularity (consumption rate) similarities display both increasing and decreasing behavior and are roughly at the same level at the beginning and end of our time range.
#
# It is interesting to realize that the difference in GDP per capita and the geographical distance result in very similar similarity curves since the last two line plots very closely resemble the first two line plots. This is probably because the GDP per capita and the geographical distance are highly correlated since the locations in the same continent (individual states of the U.S., North European countries such as Norway and Finland, etc.) have relatively close levels of wealth and are also geographically close to each other.

# %% [markdown]
# Using the t_test_dataframe() function, we perform a t-test to see if the brewery location preference difference between the mean similarity of the closest locations and the mean similarity of the farthest locations (in terms of GDP per capita) is statistically significant.

# %%
t_test_dataframe(rename_columns, closest_bc_ratings, farthest_bc_ratings, brewery_similarity_ratings, closest_bc_pop, farthest_bc_pop, brewery_similarity_popularity)
# Out:
#     year  closest vs farthest p-value based on rating  \
# 0   2006                                 1.535657e-04
# 1   2007                                 5.190301e-17
# 2   2008                                 2.307313e-06
# 3   2009                                 2.759751e-03
# 4   2010                                 5.170542e-03
# 5   2011                                 1.044563e-02
# 6   2012                                 1.193467e-02
# 7   2013                                 7.986872e-01
# 8   2014                                 2.647249e-04
# 9   2015                                 1.725976e-04
# 10  2016                                 2.640499e-03
# 11  2017                                 6.975051e-01
#
#     closest vs farthest p-value based on popularity
# 0                                      2.134336e-51
# 1                                      1.042398e-50
# 2                                      1.253635e-66
# 3                                      6.365619e-77
# 4                                      7.384161e-71
# 5                                      5.726733e-82
# 6                                      6.119069e-57
# 7                                      1.951203e-74
# 8                                      2.391749e-63
# 9                                      2.645847e-52
# 10                                     3.702835e-54
# 11                                     8.908184e-53

# %% [markdown]
# **As we can see, the p-value is lower than 0.05 in all years based on differences in both rating and consumption categories. So we can say that the brewery location preference similarity significantly differs depending on whether it is calculated among close or far locations in terms of GDP per capita. Furthermore, p-values based on popularity is much smaller than the p-values based on rating. Therefore, GDP per capita difference seems to play a bigger role on popularity (consumption rate) differences than rating differences.**

# %% [markdown]
# ## *Beer Brotherhood*

# %% [markdown]
# Wouldn't it be interesting to see which locations are the closest in terms of beer preferences? Of course, we have to keep in mind that we have four beer preference similarity metrics. To have a sensible single similarity value, we will find four beer preference similarities between each pair of locations, standardize each of the four metrics and then add them up into a single value. Then, the resulting overall similarities between each pair of locations for each year will be aggregated over the years such that we end up with a single beer preference similarity value for each pair of locations.

# %%
style_similarity_ratings_standardized = style_similarity_ratings.copy()
style_similarity_pop_standardized = style_similarity_popularity.copy()
bc_sim_ratings_standardized =brewery_similarity_ratings.copy()
bc_sim_pop_standardized =  brewery_similarity_popularity.copy()
final_res = pd.DataFrame()
final_res['location 1'] = style_similarity_ratings['location 1']
final_res['location 2'] = style_similarity_ratings['location 2']

#Standardize each metric for each year by subtracting the mean and dividing by the standard deviation (finding a z-score)
for i in range(2006, 2018):
    string_year = str(i)
    style_similarity_ratings_standardized[string_year] = style_similarity_ratings_standardized[string_year].apply(lambda x:  (x - style_similarity_ratings_standardized[string_year].mean())/style_similarity_ratings_standardized[string_year].std() )
    style_similarity_pop_standardized[string_year] = style_similarity_pop_standardized[string_year].apply(lambda x:  (x - style_similarity_pop_standardized[string_year].mean())/style_similarity_pop_standardized[string_year].std() )
    bc_sim_ratings_standardized[string_year] = bc_sim_ratings_standardized[string_year].apply(lambda x:  (x - bc_sim_ratings_standardized[string_year].mean())/bc_sim_ratings_standardized[string_year].std() )
    bc_sim_pop_standardized[string_year] = bc_sim_pop_standardized[string_year].apply(lambda x:  (x - bc_sim_pop_standardized[string_year].mean())/bc_sim_pop_standardized[string_year].std() )
    final_res[string_year] = bc_sim_pop_standardized[string_year] + bc_sim_ratings_standardized[string_year] + style_similarity_pop_standardized[string_year]+style_similarity_ratings_standardized[string_year]

# %%
#Take mean of year similarities for each pair, and get the top 10 pairs: 
year_columns = [col for col in final_res.columns if col.startswith('2')]
mean_similarities = final_res[year_columns].mean(axis=1)
final_res['mean similarity'] = mean_similarities

#Get the top ten "beer brothers" considering the overall similarity
top_10_indices = final_res['mean similarity'].nlargest(10).index
top_10_df = final_res.loc[top_10_indices, ['location 1', 'location 2', 'mean similarity']]
top_10_df
# Out:
#                          location 1                     location 2  \
# 2337        United States, New York    United States, Pennsylvania
# 1405         United States, Arizona      United States, California
# 1498      United States, California         United States, Florida
# 2332        United States, New York  United States, North Carolina
# 2090   United States, Massachusetts  United States, North Carolina
# 2095   United States, Massachusetts    United States, Pennsylvania
# 2475        United States, Virginia      United States, Washington
# 1840        United States, Illinois            United States, Ohio
# 1875         United States, Indiana            United States, Ohio
# 2350  United States, North Carolina            United States, Ohio
#
#       mean similarity
# 2337         5.336949
# 1405         5.149030
# 1498         5.010919
# 2332         4.864824
# 2090         4.854357
# 2095         4.812980
# 2475         4.810545
# 1840         4.808551
# 1875         4.645080
# 2350         4.632793

# %% [markdown]
# Unsurprisingly, all the most similar location pairs in terms of beer preferences are different states of the U.S. In order to have a more meaningful result, we need to again combine different states of the U.S. under the name 'United States' and then find the most similar location pairs. We make this update below.

# %%
final_res_filtered = final_res.copy()
final_res_filtered['location 1'] = final_res_filtered['location 1'].apply(lambda x: 'United States' if x.startswith('United States') else x)
final_res_filtered['location 2'] = final_res_filtered['location 2'].apply(lambda x: 'United States' if x.startswith('United States') else x)

#Remove line where location 1 and location 2 are the same
final_res_filtered = final_res_filtered[final_res_filtered['location 1'] != final_res_filtered['location 2']]

#Take the mean of the lines that have the same location 1 and 2
final_res_filtered = final_res_filtered.groupby(['location 1', 'location 2']).mean().reset_index()

# %% [markdown]
# We know have the preference similarities between each pair of locations for each year. We now aggregate the similarities over the years and find the most similar location pairs. We also find the least similar location pairs to see if there are any interesting results.

# %%
year_columns = [col for col in final_res_filtered.columns if col.startswith('2')]
mean_similarities = final_res_filtered[year_columns].mean(axis=1)
final_res_filtered['mean similarity'] = mean_similarities
top_3_indices_filtered = final_res_filtered['mean similarity'].nlargest(3).index
bottom_3_indices_filtered = final_res_filtered['mean similarity'].nsmallest(3).index
top_3_df_filtered = final_res_filtered.loc[top_3_indices_filtered, ['location 1', 'location 2', 'mean similarity']]
bottom_3_df_filtered = final_res_filtered.loc[bottom_3_indices_filtered, ['location 1', 'location 2', 'mean similarity']]

# %% [markdown]
# ### **Top 3 most similar country pairs in terms of beer preference - a.k.a. Beer Brothers:**

# %%
top_3_df_filtered
# Out:
#     location 1   location 2  mean similarity
# 129    England     Scotland         3.540168
# 34     Belgium  Netherlands         2.216442
# 142    Finland       Norway         1.934942

# %% [markdown]
# The results definitely make sense as we know these are culturally similar pair of countries.

# %% [markdown]
# ### **Top 3 least similar country pairs in terms of beer preference - a.k.a. Beer Enemies:**

# %%
bottom_3_df_filtered
# Out:
#     location 1 location 2  mean similarity
# 162    Germany    Iceland        -2.794392
# 9    Australia    Iceland        -2.715598
# 104    Denmark    Iceland        -2.692922

# %% [markdown]
# It looks like Iceland has the highest number of beer enemies to watch out for!

# %% [markdown]
# ## *Investigating the correlation of GDP per capita difference or geographic distance between locations to their beer preference similarities*

# %% [markdown]
# We now have a single similarity value for each pair of locations. As the last step, want to see if there is a correlation between the similarity of beer preferences between two locations and their GDP per capita difference or geographic distance. Then, we can calculate the correlation coefficient between the similarity of beer preferences and GDP per capita difference or geographic distance. We use the correlation_coefficient() function defined in helpers.py file to calculate the correlation coefficient using pearsonr() function from scipy.stats library. Then, we plot the correlation coefficients versus year.

# %%
correlation_similarity_distance, _ = correlation_coefficient(final_res, ll_dict, distance=True)
correlation_similarity_wealth, _ = correlation_coefficient(final_res, wealth_dict, distance=False)

# %%
plot_correlation(correlation_similarity_distance, 'Correlation between geographic distance and beer preference similarity')

# %% [markdown]
# There is no apparent trend in the correlation coefficient versus time. However, the correlation coefficient is negative across all years, which means that the beer preference similarity decreases as the geographic distance between the locations increases. This conforms with the intuition. Let's also look at the correlation averaged over the years:

# %%
print(f"Correlation between geographic distance and beer preference similarity averaged over the years is: {np.array(list(correlation_similarity_distance.values())).mean():2f}")
# Out:
# Correlation between geographic distance and beer preference similarity averaged over the years is: -0.426826

# %%
plot_correlation(correlation_similarity_wealth, 'Correlation between GDP per capita difference and beer preference similarity')

# %% [markdown]
# There is no apparent trend in the correlation coefficient versus time. However, the correlation coefficient is negative across all years, which means that the beer preference similarity decreases as the GDP per capita difference between the locations increases. Again, this conforms with the intuition. Let's also look at the correlation averaged over the years:

# %%
print(f"Correlation between GDP per capita difference and beer preference similarity averaged over the years is: {np.array(list(correlation_similarity_wealth.values())).mean():2f}")
# Out:
# Correlation between GDP per capita difference and beer preference similarity averaged over the years is: -0.228543

# %% [markdown]
# Although both of the correlation coefficients are negative, the correlation coefficient between geographic distance and beer preference similarity is much more negative (higher in absolute value) than the correlation coefficient between GDP per capita difference and beer preference similarity. This means that the geographic distance between locations is a better predictor of beer preference similarity than the GDP per capita difference between locations.
